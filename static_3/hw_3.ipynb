# %%
from sklearn.datasets import fetch_california_housing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy.stats import pearsonr, spearmanr, kendalltau
# %matplotlib inline

# %%
data = fetch_california_housing(as_frame=True, return_X_y=True)
df, target = data[0], data[1]

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df.shape
# Out:
# (20640, 8)

# %%
sns.histplot(df.MedInc, bins=15, kde=True)
plt.show()

# %%
np.median(df.MedInc) - np.mean(df.MedInc)

# %%
sns.histplot(df.HouseAge, bins=15, kde=True)
plt.show()

# %%
print(f" Разницы медианы и среднего для медианного дохода =  {np.median(df.MedInc) - np.mean(df.MedInc)}",
      f" Разницы медианы и среднего для возраста дома =  {(np.median(df.HouseAge) - np.mean(df.HouseAge))/5}")
# Out:
#  Разницы медианы и среднего для медианного дохода =  -0.3358710029069769  Разницы медианы и среднего для возраста дома =  0.07210271317829467

# %%
q25, q75 = np.quantile(target, q=[0.25, 0.75])
print(q75-q25)
# Out:
# 1.4512499999999997

# %%
#из подсказок
scipy.stats.iqr(x = target)
# Out:
# 1.4512499999999997

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
print('Корреляция Пирсона для MedInc и target:  ', pearsonr(df['MedInc'], target)[0])
print('Корреляция Пирсона для HouseAge и target:  ', pearsonr(df['HouseAge'], target)[0])
print('Корреляция Пирсона для AveRooms и target:  ', pearsonr(df['AveRooms'], target)[0])
print('Корреляция Пирсона для AveBedrms и target:  ', pearsonr(df['AveBedrms'], target)[0])
print('Корреляция Пирсона для Population и target:  ', pearsonr(df['Population'], target)[0])
print('Корреляция Пирсона для AveOccup и target:  ', pearsonr(df['AveOccup'], target)[0])
# Out:
# Корреляция Пирсона для MedInc и target:   0.688075207958547
# Корреляция Пирсона для HouseAge и target:   0.10562341249320953
# Корреляция Пирсона для AveRooms и target:   0.15194828974145774
# Корреляция Пирсона для AveBedrms и target:   -0.046700512969486775
# Корреляция Пирсона для Population и target:   -0.024649678888894907
# Корреляция Пирсона для AveOccup и target:   -0.023737412956134303

# %%
print('Корреляция Cпирмена для MedInc и target:  ', spearmanr(df['MedInc'], target)[0])
print('Корреляция Cпирмена для HouseAge и target:  ', spearmanr(df['HouseAge'], target)[0])
print('Корреляция Cпирмена для AveRooms и target:  ', spearmanr(df['AveRooms'], target)[0])
print('Корреляция Cпирмена для AveBedrms и target:  ', spearmanr(df['AveBedrms'], target)[0])
print('Корреляция Cпирмена для Population и target:  ', spearmanr(df['Population'], target)[0])
print('Корреляция Cпирмена для AveOccup и target:  ', spearmanr(df['AveOccup'], target)[0])
# Out:
# Корреляция Cпирмена для MedInc и target:   0.6767781095942506
# Корреляция Cпирмена для HouseAge и target:   0.07485485302251019
# Корреляция Cпирмена для AveRooms и target:   0.26336668772954447
# Корреляция Cпирмена для AveBedrms и target:   -0.12518706503579644
# Корреляция Cпирмена для Population и target:   0.0038387551282557182
# Корреляция Cпирмена для AveOccup и target:   -0.25659376466389333

# %%
print('Корреляция Кендалла для MedInc и target:  ', kendalltau(df['MedInc'], target)[0])
print('Корреляция Кендалла для HouseAge и target:  ', kendalltau(df['HouseAge'], target)[0])
print('Корреляция Кендалла для AveRooms и target:  ', kendalltau(df['AveRooms'], target)[0])
print('Корреляция Кендалла для AveBedrms и target:  ', kendalltau(df['AveBedrms'], target)[0])
print('Корреляция Кендалла для Population и target:  ', kendalltau(df['Population'], target)[0])
print('Корреляция Кендалла для AveOccup и target:  ', kendalltau(df['AveOccup'], target)[0])
# Out:
# Корреляция Кендалла для MedInc и target:   0.49552824412670066
# Корреляция Кендалла для HouseAge и target:   0.04982226998977426
# Корреляция Кендалла для AveRooms и target:   0.17917481650845044
# Корреляция Кендалла для AveBedrms и target:   -0.08348903017545448
# Корреляция Кендалла для Population и target:   0.0021720742963692403
# Корреляция Кендалла для AveOccup и target:   -0.17437025760436126

# %%
pd.merge(df.reset_index(), target.reset_index()).corr()
# Out:
#                 index    MedInc  HouseAge  AveRooms  AveBedrms  Population  \
# index        1.000000  0.071673 -0.181132  0.042471  -0.011169    0.024880
# MedInc       0.071673  1.000000 -0.119034  0.326895  -0.062040    0.004834
# HouseAge    -0.181132 -0.119034  1.000000 -0.153277  -0.077747   -0.296244
# AveRooms     0.042471  0.326895 -0.153277  1.000000   0.847621   -0.072213
# AveBedrms   -0.011169 -0.062040 -0.077747  0.847621   1.000000   -0.066197
# Population   0.024880  0.004834 -0.296244 -0.072213  -0.066197    1.000000
# AveOccup     0.005545  0.018766  0.013191 -0.004852  -0.006181    0.069863
# Latitude     0.081062 -0.079809  0.011173  0.106389   0.069721   -0.108785
# Longitude   -0.113254 -0.015176 -0.108197 -0.027540   0.013344    0.099773
# MedHouseVal  0.072086  0.688075  0.105623  0.151948  -0.046701   -0.024650
#
#              AveOccup  Latitude  Longitude  MedHouseVal
# index        0.005545  0.081062  -0.113254     0.072086
# ...

# %%
pd.merge(df.reset_index(), target.reset_index()).corr()
# Out:
#                 index    MedInc  HouseAge  AveRooms  AveBedrms  Population  \
# index        1.000000  0.071673 -0.181132  0.042471  -0.011169    0.024880
# MedInc       0.071673  1.000000 -0.119034  0.326895  -0.062040    0.004834
# HouseAge    -0.181132 -0.119034  1.000000 -0.153277  -0.077747   -0.296244
# AveRooms     0.042471  0.326895 -0.153277  1.000000   0.847621   -0.072213
# AveBedrms   -0.011169 -0.062040 -0.077747  0.847621   1.000000   -0.066197
# Population   0.024880  0.004834 -0.296244 -0.072213  -0.066197    1.000000
# AveOccup     0.005545  0.018766  0.013191 -0.004852  -0.006181    0.069863
# Latitude     0.081062 -0.079809  0.011173  0.106389   0.069721   -0.108785
# Longitude   -0.113254 -0.015176 -0.108197 -0.027540   0.013344    0.099773
# MedHouseVal  0.072086  0.688075  0.105623  0.151948  -0.046701   -0.024650
#
#              AveOccup  Latitude  Longitude  MedHouseVal
# index        0.005545  0.081062  -0.113254     0.072086
# ...

# %%
df = scipy.stats.zscore(df)
target = scipy.stats.zscore(target)

# %%
df.head()
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  2.344766  0.982143  0.628559  -0.153758   -0.974429 -0.049597  1.052548
# 1  2.332238 -0.607019  0.327041  -0.263336    0.861439 -0.092512  1.043185
# 2  1.782699  1.856182  1.155620  -0.049016   -0.820777 -0.025843  1.038503
# 3  0.932968  1.856182  0.156966  -0.049833   -0.766028 -0.050329  1.038503
# 4 -0.012881  1.856182  0.344711  -0.032906   -0.759847 -0.085616  1.038503
#
#    Longitude
# 0  -1.327835
# 1  -1.322844
# 2  -1.332827
# 3  -1.337818
# 4  -1.337818

# %%
print('Корреляция Пирсона для MedInc и target:  ', pearsonr(df['MedInc'], target)[0])
print('Корреляция Пирсона для HouseAge и target:  ', pearsonr(df['HouseAge'], target)[0])
print('Корреляция Пирсона для AveRooms и target:  ', pearsonr(df['AveRooms'], target)[0])
print('Корреляция Пирсона для AveBedrms и target:  ', pearsonr(df['AveBedrms'], target)[0])
print('Корреляция Пирсона для Population и target:  ', pearsonr(df['Population'], target)[0])
print('Корреляция Пирсона для AveOccup и target:  ', pearsonr(df['AveOccup'], target)[0])
# Out:
# Корреляция Пирсона для MedInc и target:   0.6880752079585479
# Корреляция Пирсона для HouseAge и target:   0.10562341249320939
# Корреляция Пирсона для AveRooms и target:   0.15194828974145808
# Корреляция Пирсона для AveBedrms и target:   -0.046700512969486865
# Корреляция Пирсона для Population и target:   -0.024649678888894876
# Корреляция Пирсона для AveOccup и target:   -0.02373741295613435

# %%
print('Корреляция Cпирмена для MedInc и target:  ', spearmanr(df['MedInc'], target)[0])
print('Корреляция Cпирмена для HouseAge и target:  ', spearmanr(df['HouseAge'], target)[0])
print('Корреляция Cпирмена для AveRooms и target:  ', spearmanr(df['AveRooms'], target)[0])
print('Корреляция Cпирмена для AveBedrms и target:  ', spearmanr(df['AveBedrms'], target)[0])
print('Корреляция Cпирмена для Population и target:  ', spearmanr(df['Population'], target)[0])
print('Корреляция Cпирмена для AveOccup и target:  ', spearmanr(df['AveOccup'], target)[0])
# Out:
# Корреляция Cпирмена для MedInc и target:   0.6767781095942506
# Корреляция Cпирмена для HouseAge и target:   0.07485485302251019
# Корреляция Cпирмена для AveRooms и target:   0.26336668772954447
# Корреляция Cпирмена для AveBedrms и target:   -0.12518706503579644
# Корреляция Cпирмена для Population и target:   0.0038387551282557182
# Корреляция Cпирмена для AveOccup и target:   -0.25659376466389333

# %%
print('Корреляция Кендалла для MedInc и target:  ', kendalltau(df['MedInc'], target)[0])
print('Корреляция Кендалла для HouseAge и target:  ', kendalltau(df['HouseAge'], target)[0])
print('Корреляция Кендалла для AveRooms и target:  ', kendalltau(df['AveRooms'], target)[0])
print('Корреляция Кендалла для AveBedrms и target:  ', kendalltau(df['AveBedrms'], target)[0])
print('Корреляция Кендалла для Population и target:  ', kendalltau(df['Population'], target)[0])
print('Корреляция Кендалла для AveOccup и target:  ', kendalltau(df['AveOccup'], target)[0])
# Out:
# Корреляция Кендалла для MedInc и target:   0.49552824412670066
# Корреляция Кендалла для HouseAge и target:   0.04982226998977426
# Корреляция Кендалла для AveRooms и target:   0.17917481650845044
# Корреляция Кендалла для AveBedrms и target:   -0.08348903017545448
# Корреляция Кендалла для Population и target:   0.0021720742963692403
# Корреляция Кендалла для AveOccup и target:   -0.17437025760436126

# %%
#Приглядимся к AveRooms
print('Пирсон:  ', pearsonr(df.AveRooms, target)[0])
print('Спирман: ', spearmanr(df.AveRooms, target)[0])
print('Кендалл: ', kendalltau(df.AveRooms, target)[0])
# Out:
# Пирсон:   0.15194828974145808
# Спирман:  0.26336668772954447
# Кендалл:  0.17917481650845044

# %%
sns.histplot(df.AveRooms, bins=np.arange(0, 5, 0.5),
    color='orange', alpha=0.7)
plt.show()

# %%
data = pd.merge(df.reset_index(), target.reset_index())

# %%
data.head()
# Out:
#    index    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      0  2.344766  0.982143  0.628559  -0.153758   -0.974429 -0.049597
# 1      1  2.332238 -0.607019  0.327041  -0.263336    0.861439 -0.092512
# 2      2  1.782699  1.856182  1.155620  -0.049016   -0.820777 -0.025843
# 3      3  0.932968  1.856182  0.156966  -0.049833   -0.766028 -0.050329
# 4      4 -0.012881  1.856182  0.344711  -0.032906   -0.759847 -0.085616
#
#    Latitude  Longitude  MedHouseVal
# 0  1.052548  -1.327835     2.129631
# 1  1.043185  -1.322844     1.314156
# 2  1.038503  -1.332827     1.258693
# 3  1.038503  -1.337818     1.165100
# 4  1.038503  -1.337818     1.172900

# %%
pd.merge(df.reset_index(), target.reset_index())

# %%
treshold_min = data["AveRooms"].quantile(0.025)
treshold_max = data["AveRooms"].quantile(0.975)

# %%
data = data.mask(data["AveRooms"] < treshold_min).dropna()

# %%
data = data.mask(data["AveRooms"] > treshold_max).dropna()

# %%
print('Пирсон:  ', pearsonr(data.AveRooms, data.MedHouseVal)[0])
print('Спирман: ', spearmanr(data.AveRooms, data.MedHouseVal)[0])
print('Кендалл: ', kendalltau(data.AveRooms, data.MedHouseVal)[0])
# Out:
# Пирсон:   0.28223076834862393
# Спирман:  0.2502033644961814
# Кендалл:  0.16886114485999829

# %%
sns.heatmap(df.corr(method='pearson'), vmin=-1, vmax=1, annot=True)
plt.show()
