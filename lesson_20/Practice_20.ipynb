# %%
import warnings
warnings.filterwarnings('ignore')

# %%
### Установим красивые дефолтные настройки
### Может быть лень постоянно прописывать
### У графиков параметры цвета, размера, шрифта
### Можно положить их в словарь дефолтных настроек

import matplotlib as mlp

mlp.rcParams['lines.linewidth'] = 5

mlp.rcParams['xtick.major.size'] = 20
mlp.rcParams['xtick.major.width'] = 5
mlp.rcParams['xtick.labelsize'] = 20
mlp.rcParams['xtick.color'] = '#FF5533'

mlp.rcParams['ytick.major.size'] = 20
mlp.rcParams['ytick.major.width'] = 5
mlp.rcParams['ytick.labelsize'] = 20
mlp.rcParams['ytick.color'] = '#FF5533'

mlp.rcParams['axes.labelsize'] = 20
mlp.rcParams['axes.titlesize'] = 20
mlp.rcParams['axes.titlecolor'] = '#00B050'
mlp.rcParams['axes.labelcolor'] = '#00B050'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = 500

# %% [markdown]
# ### Gradient Boosting

# %%
### Генерим датасет

from sklearn.datasets import make_moons

dataset = make_moons(n_samples=1000,
                     noise=0.5,
                     random_state=0)

dataset = pd.DataFrame(np.hstack((dataset[0], dataset[1].reshape(-1, 1))),
                       columns=["x1", "x2", "y"])

dataset.head()
# Out:
#          x1        x2    y
# 0  2.216430  0.741684  1.0
# 1  2.057427  0.424853  1.0
# 2 -0.116847  0.004159  0.0
# 3 -0.710797  0.210482  1.0
# 4  0.267548 -0.460654  1.0

# %%
### Изобразим объекты и раскрасим их в классы

import seaborn as sns

fig = plt.figure()

fig.set_size_inches(16, 10)

sns.scatterplot(x="x1",
                y="x2",
                hue="y",
                edgecolor="k",
                palette=["#FF5533", "#00B050"],
                data=dataset)

plt.show()

# %%
### Разобьем датасет на объекты и таргеты

X = dataset.drop("y", axis=1)
y = dataset["y"]

### Разделим на трейн и тест

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    random_state=0, 
                                                    test_size=0.2)

# %%
### Обучим градиентный бустинг над деревьями

from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier(learning_rate=1,
                                   max_depth=2,
                                   n_estimators=500)
#learning_rate - множитель каждой модели в ансамбле моделей
model
# Out:
# GradientBoostingClassifier(learning_rate=1, max_depth=2, n_estimators=500)

# %%
model.n_estimators
# Out:
# 500

# %%
def learn_boosting_and_plot(estimator=model,
                            X_tr=X_train,
                            X_te=X_test,
                            Y_tr=y_train,
                            Y_te=y_test):
    
    pixel_step = 0.02
    
    X = pd.concat((X_tr, X_te))
    Y = pd.concat((Y_tr, Y_te))
    
    x1_min, x1_max = X.values[:, 0].min() - 1, X.values[:, 0].max() + 1
    x2_min, x2_max = X.values[:, 1].min() - 1, X.values[:, 1].max() + 1

    ### Генерим много-много точек на плоскости

    xx1, xx2 = np.meshgrid(
        np.arange(x1_min, x1_max, pixel_step),
        np.arange(x2_min, x2_max, pixel_step)
    )

    
    ### Обучаем модель на трейне
    
    estimator.fit(X_tr, Y_tr)
    
    ### Считаем качество на обоих фолдах
    
    accuracy_train = estimator.score(X_tr, Y_tr)
    accuracy_test = estimator.score(X_te, Y_te)
    
    ### Для каждой точки даем прогноз, чтобы покрыть поверхности

    Z = estimator.predict(np.c_[xx1.ravel(), xx2.ravel()])
    Z = Z.reshape(xx1.shape)

    ### Заполняем пространство

    cs = plt.contourf(xx1, xx2, Z, cmap=plt.cm.Paired)

    plt.axis("tight")

    ### Рисуем точечки и обученные области

    for i, n, c in zip(range(2), model.classes_, ["#FF5533", "#00B050"]):
        idx = np.where(y == i)
        plt.scatter(
            X.values[idx, 0],
            X.values[idx, 1],
            c=c,
            s=20,
            edgecolor="k",
            label="Class %s" % n,
        )
    plt.xlim(x1_min, x1_max)
    plt.ylim(x2_min, x2_max)
    plt.legend(loc="upper right")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.title(f"Boosting with {estimator.n_estimators} estimators")
    
    return accuracy_train, accuracy_test

# %%
learn_boosting_and_plot(model)
# Out:
# (1.0, 0.755)

# %%
estimators_num = [1, 5, 10, 25, 50, 100, 200, 500, 1000, 3000]

fig = plt.figure()
fig.set_size_inches(20, 50)

train_accuracies = []
test_accuracies = []


for i, s in enumerate(estimators_num):
    
    model.n_estimators = s
    ax_ = fig.add_subplot(5, 2, i+1)
    
    outputs = learn_boosting_and_plot(model)
    
    train_accuracies.append(outputs[0])
    test_accuracies.append(outputs[1])

fig.tight_layout()
plt.show()

# %%
### Изобразим кривые качества на трейне и тесте

fig = plt.figure()
fig.set_size_inches(15, 5)

ax_1 = fig.add_subplot(1, 2, 1)
plt.plot(estimators_num, train_accuracies)

ax_2 = fig.add_subplot(1, 2, 2)
plt.plot(estimators_num, test_accuracies)

plt.show()

# %% [markdown]
# ### Поменяем learning_rate и посмотрим, как замедлится композиция!

# %%
### Обучим градиентный бустинг над деревьями

from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier(learning_rate=0.1,
                                   max_depth=2,
                                   n_estimators=500)

model
# Out:
# GradientBoostingClassifier(max_depth=2, n_estimators=500)

# %%
estimators_num = [1, 5, 10, 25, 50, 100, 200, 500, 1000, 3000]

fig = plt.figure()
fig.set_size_inches(20, 50)

train_accuracies = []
test_accuracies = []


for i, s in enumerate(estimators_num):
    
    model.n_estimators = s
    ax_ = fig.add_subplot(5, 2, i+1)
    
    outputs = learn_boosting_and_plot(model)
    
    train_accuracies.append(outputs[0])
    test_accuracies.append(outputs[1])

fig.tight_layout()
plt.show()

# %%
### Изобразим кривые качества на трейне и тесте

fig = plt.figure()
fig.set_size_inches(15, 5)

ax_1 = fig.add_subplot(1, 2, 1)
plt.plot(estimators_num, train_accuracies)

ax_2 = fig.add_subplot(1, 2, 2)
plt.plot(estimators_num, test_accuracies)

plt.show()

# %% [markdown]
# ### Популярные реализации градиентного бустинга

# %% [markdown]
# ### XGboost

# %% [markdown]
# $$
# \sum_i^n L(y_i, a^{(N-1)}(x_i) + b_N (x_i)) \rightarrow min
# $$
#
# Ряд Тейлора:
#
# $$
# e^x = 1 + \frac{x}{1!} + \frac{x^2}{2!} + \frac{x^3}{3!} + ...
# $$
#
# Можно применять и в многомерном случае
#
# $$
# \sum_i^n L(y_i, a^{(N-1)}(x_i) + b_N (x_i)) \approx \sum_i^n (L(y_i, a^{(N-1)}(x_i)) - s_i \cdot b(x_i) + \frac{1}{2}\cdot h_i \cdot b^2(x_i))
# $$
#
# где через $h_i$ обозначены вторые производные по сдвигам
#
# Если вместо $h_i$ положить единички, то получится ровно та задача аппроксимации сдвигов, которую решает обычный градиентный бустинг:
#
# $$
# \sum_i^n (b(x_i)-s_i)^2 = \sum_i^n (b^2(x_i) - 2\cdot s_i \cdot b(x_i) + s_i^2) =
# $$
#
# $$
# \sum_i^n ( - 2\cdot s_i \cdot b(x_i) + b^2(x_i) + s_i^2) = 2 \cdot \sum_i^n (- s_i \cdot b(x_i) + \frac{1}{2} \cdot b^2 (x_i) + \frac{1}{2} + s_i^2)
# $$
#
# При оптимизации константы как множитель и как слагаемое можно опустить:
#
# $$
# \sum_i^n (- s_i \cdot b(x_i) + \frac{1}{2} \cdot b^2 (x_i)) \rightarrow min
# $$
#
# Таким образом, XGboost совершенствует классический градиентный бустинг тем фактом, что при приближении сдвигов новым алгоритмом еще и учитывает вторые производные (кривизну) изначально минимизируемого функционала. Так же в XGboost реализациях обычно учитывается регуляризация деревьев типа
#
# $$
# \sum_i^n (- s_i \cdot b(x_i) + \frac{1}{2} \cdot b^2 (x_i)) + \gamma \cdot J + \frac{\lambda}{2}\cdot \sum_j^J b_j^2 \rightarrow min
# $$
#
# Считается самым оптимизированным бустингом: огромное комьюнити, перебор порогов осуществляется с некоторым шагом, а не полным перебором и т.д.

# %% [markdown]
# ### Catboost

# %% [markdown]
# Реализация Яндекса, обладающая рядом особенностей:
#
# 1. Симметричные деревья
# 2. Встроенная обработка категориальных признаков
# 3. Позволяет строить вершины с большим количеством потомков (например, может классно работать при наличии категорий с большим количеством уникальных значений)
# 4. Бустрапирует выборку при обучении
# 5. и т.д.
#
# Наверное, стоит сказать, что это лучшее решение, работающее из коробки без особого подбора гиперпараметров.
#
# ![catboost.png](data:image/png;base64,...)

# %% [markdown]
# ### LightGBM

# %% [markdown]
# Разработка Microsoft!
#
# 1. С точки зрения работы с категориями, делит их на 2 подгруппы и работает как с бинарной категорией
# 2. Строит односторонние деревья, из-за чего почти всегда опережает остальные реализации по скорости работы
#
# ![lgbm.png](data:image/png;base64,...)

# %% [markdown]
# ### Бустинг в реальной задаче и сравнение результатов с бэггингом

# %%
X_train = pd.read_csv("X_train_updated.csv")
X_test = pd.read_csv("X_test_updated.csv")

y_train = pd.read_csv("y_train_updated.csv")
y_test = pd.read_csv("y_test_updated.csv")

object_cols = ['store_nbr', 'item_nbr', 'onpromotion', 'month',
               'city', 'state', 'type', 'cluster', 'family',
               'class', 'perishable', 'holiday_type', 'locale',
               'locale_name', 'description', 'transferred']

X_test[object_cols] = X_test[object_cols].astype(str)
X_train[object_cols] = X_train[object_cols].astype(str)

cols_for_ohe = [x for x in object_cols if X_train[x].nunique() < 5]
cols_for_mte = [x for x in object_cols if X_train[x].nunique() >= 5]
numeric_cols = list(X_train.select_dtypes(exclude='object').columns)

cols_for_ohe_idx = [list(X_train.columns).index(col) for col in cols_for_ohe]
cols_for_mte_idx = [list(X_train.columns).index(col) for col in cols_for_mte]
numeric_cols_idx = [list(X_train.columns).index(col) for col in numeric_cols]

cat_cols = cols_for_ohe_idx + cols_for_mte_idx

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (1.0.5)
# Requirement already satisfied: scipy in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from catboost) (1.7.3)
# Requirement already satisfied: matplotlib in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from catboost) (3.5.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from catboost) (1.21.4)
# Requirement already satisfied: plotly in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from catboost) (5.8.0)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from catboost) (1.3.4)
# Requirement already satisfied: six in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: graphviz in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from catboost) (0.20)
# Requirement already satisfied: packaging>=20.0 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->catboost) (4.28.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->catboost) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from matplotlib->catboost) (3.0.6)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from plotly->catboost) (8.0.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\gigabyte\appdata\local\programs\python\python37\lib\site-packages (from pandas>=0.24.0->catboost) (2019.2)
# WARNING: You are using pip version 20.1.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'c:\users\gigabyte\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
from catboost import CatBoostRegressor

catboost = CatBoostRegressor()

catboost.fit(X_train, y_train, cat_features=cat_cols)
# Out:
# Learning rate set to 0.067399
# 0:	learn: 0.8430170	total: 212ms	remaining: 3m 31s
# 1:	learn: 0.8142942	total: 248ms	remaining: 2m 3s
# 2:	learn: 0.7885545	total: 285ms	remaining: 1m 34s
# 3:	learn: 0.7649458	total: 317ms	remaining: 1m 18s
# 4:	learn: 0.7434233	total: 355ms	remaining: 1m 10s
# 5:	learn: 0.7242734	total: 390ms	remaining: 1m 4s
# 6:	learn: 0.7070885	total: 430ms	remaining: 1m 1s
# 7:	learn: 0.6909883	total: 465ms	remaining: 57.6s
# 8:	learn: 0.6760970	total: 500ms	remaining: 55.1s
# 9:	learn: 0.6632929	total: 534ms	remaining: 52.9s
# 10:	learn: 0.6514407	total: 572ms	remaining: 51.5s
# 11:	learn: 0.6409061	total: 606ms	remaining: 49.9s
# 12:	learn: 0.6314310	total: 644ms	remaining: 48.9s
# 13:	learn: 0.6225399	total: 679ms	remaining: 47.8s
# 14:	learn: 0.6145038	total: 717ms	remaining: 47.1s
# 15:	learn: 0.6075041	total: 750ms	remaining: 46.2s
# 16:	learn: 0.6011346	total: 787ms	remaining: 45.5s
# 17:	learn: 0.5949747	total: 821ms	remaining: 44.8s
# 18:	learn: 0.5896610	total: 860ms	remaining: 44.4s
# 19:	learn: 0.5846100	total: 897ms	remaining: 43.9s
# 20:	learn: 0.5801413	total: 935ms	remaining: 43.6s
# 21:	learn: 0.5767395	total: 968ms	remaining: 43s
# 22:	learn: 0.5729694	total: 1s	remaining: 42.7s
# 23:	learn: 0.5697402	total: 1.04s	remaining: 42.2s
# 24:	learn: 0.5668252	total: 1.07s	remaining: 42s
# 25:	learn: 0.5640024	total: 1.11s	remaining: 41.6s
# 26:	learn: 0.5614313	total: 1.15s	remaining: 41.4s
# 27:	learn: 0.5593370	total: 1.18s	remaining: 41.1s
# 28:	learn: 0.5573533	total: 1.22s	remaining: 40.9s
# 29:	learn: 0.5556187	total: 1.25s	remaining: 40.5s
# 30:	learn: 0.5533240	total: 1.29s	remaining: 40.4s
# 31:	learn: 0.5516181	total: 1.33s	remaining: 40.2s
# 32:	learn: 0.5500351	total: 1.37s	remaining: 40s
# 33:	learn: 0.5485010	total: 1.4s	remaining: 39.8s
# 34:	learn: 0.5474481	total: 1.44s	remaining: 39.6s
# 35:	learn: 0.5463889	total: 1.47s	remaining: 39.4s
# 36:	learn: 0.5451812	total: 1.51s	remaining: 39.2s
# 37:	learn: 0.5438121	total: 1.54s	remaining: 39s
# 38:	learn: 0.5427314	total: 1.58s	remaining: 38.9s
# 39:	learn: 0.5420285	total: 1.61s	remaining: 38.8s
# 40:	learn: 0.5411762	total: 1.65s	remaining: 38.7s
# 41:	learn: 0.5403847	total: 1.69s	remaining: 38.4s
# 42:	learn: 0.5396775	total: 1.72s	remaining: 38.3s
# 43:	learn: 0.5387328	total: 1.75s	remaining: 38.1s
# 44:	learn: 0.5379455	total: 1.79s	remaining: 38s
# 45:	learn: 0.5373872	total: 1.82s	remaining: 37.8s
# 46:	learn: 0.5368372	total: 1.86s	remaining: 37.7s
# 47:	learn: 0.5363868	total: 1.89s	remaining: 37.6s
# 48:	learn: 0.5358693	total: 1.93s	remaining: 37.5s
# 49:	learn: 0.5353813	total: 1.97s	remaining: 37.4s
# 50:	learn: 0.5350361	total: 2.07s	remaining: 38.5s
# 51:	learn: 0.5345893	total: 2.1s	remaining: 38.3s
# 52:	learn: 0.5341619	total: 2.14s	remaining: 38.2s
# 53:	learn: 0.5338332	total: 2.17s	remaining: 38.1s
# 54:	learn: 0.5332468	total: 2.28s	remaining: 39.2s
# 55:	learn: 0.5329292	total: 2.32s	remaining: 39.1s
# 56:	learn: 0.5325050	total: 2.35s	remaining: 39s
# 57:	learn: 0.5320632	total: 2.44s	remaining: 39.7s
# 58:	learn: 0.5314982	total: 2.5s	remaining: 40s
# 59:	learn: 0.5311631	total: 2.54s	remaining: 39.7s
# 60:	learn: 0.5306178	total: 2.57s	remaining: 39.6s
# 61:	learn: 0.5302558	total: 2.61s	remaining: 39.4s
# 62:	learn: 0.5299862	total: 2.68s	remaining: 39.9s
# 63:	learn: 0.5295755	total: 2.72s	remaining: 39.8s
# 64:	learn: 0.5293648	total: 2.76s	remaining: 39.7s
# 65:	learn: 0.5290566	total: 2.79s	remaining: 39.5s
# 66:	learn: 0.5287931	total: 2.83s	remaining: 39.4s
# 67:	learn: 0.5285603	total: 2.86s	remaining: 39.2s
# 68:	learn: 0.5283822	total: 2.97s	remaining: 40.1s
# 69:	learn: 0.5280267	total: 3.01s	remaining: 40s
# 70:	learn: 0.5278364	total: 3.08s	remaining: 40.3s
# 71:	learn: 0.5276153	total: 3.11s	remaining: 40.1s
# 72:	learn: 0.5274043	total: 3.14s	remaining: 39.9s
# 73:	learn: 0.5270439	total: 3.18s	remaining: 39.7s
# 74:	learn: 0.5268262	total: 3.21s	remaining: 39.7s
# 75:	learn: 0.5265385	total: 3.25s	remaining: 39.5s
# 76:	learn: 0.5263223	total: 3.31s	remaining: 39.6s
# 77:	learn: 0.5261268	total: 3.34s	remaining: 39.5s
# 78:	learn: 0.5259777	total: 3.38s	remaining: 39.4s
# 79:	learn: 0.5257903	total: 3.41s	remaining: 39.2s
# 80:	learn: 0.5255391	total: 3.45s	remaining: 39.1s
# 81:	learn: 0.5253410	total: 3.48s	remaining: 39s
# 82:	learn: 0.5251413	total: 3.52s	remaining: 38.9s
# 83:	learn: 0.5248893	total: 3.55s	remaining: 38.8s
# 84:	learn: 0.5247257	total: 3.59s	remaining: 38.7s
# 85:	learn: 0.5246081	total: 3.63s	remaining: 38.5s
# 86:	learn: 0.5244594	total: 3.69s	remaining: 38.8s
# 87:	learn: 0.5242259	total: 3.73s	remaining: 38.6s
# 88:	learn: 0.5240996	total: 3.76s	remaining: 38.5s
# 89:	learn: 0.5238561	total: 3.8s	remaining: 38.4s
# 90:	learn: 0.5237088	total: 3.85s	remaining: 38.5s
# 91:	learn: 0.5235327	total: 3.89s	remaining: 38.4s
# 92:	learn: 0.5232842	total: 3.92s	remaining: 38.3s
# 93:	learn: 0.5230441	total: 3.96s	remaining: 38.1s
# 94:	learn: 0.5229575	total: 4s	remaining: 38.1s
# 95:	learn: 0.5225800	total: 4.03s	remaining: 38s
# 96:	learn: 0.5224546	total: 4.07s	remaining: 37.9s
# 97:	learn: 0.5223416	total: 4.1s	remaining: 37.7s
# 98:	learn: 0.5221519	total: 4.14s	remaining: 37.7s
# 99:	learn: 0.5219057	total: 4.17s	remaining: 37.6s
# 100:	learn: 0.5217127	total: 4.21s	remaining: 37.5s
# 101:	learn: 0.5215552	total: 4.28s	remaining: 37.7s
# 102:	learn: 0.5212803	total: 4.35s	remaining: 37.9s
# 103:	learn: 0.5210961	total: 4.38s	remaining: 37.8s
# 104:	learn: 0.5209757	total: 4.42s	remaining: 37.7s
# 105:	learn: 0.5207807	total: 4.45s	remaining: 37.6s
# 106:	learn: 0.5206740	total: 4.49s	remaining: 37.5s
# 107:	learn: 0.5206049	total: 4.53s	remaining: 37.4s
# 108:	learn: 0.5205321	total: 4.56s	remaining: 37.3s
# 109:	learn: 0.5202975	total: 4.59s	remaining: 37.2s
# 110:	learn: 0.5201841	total: 4.63s	remaining: 37.1s
# 111:	learn: 0.5200539	total: 4.67s	remaining: 37s
# 112:	learn: 0.5199233	total: 4.71s	remaining: 36.9s
# 113:	learn: 0.5198367	total: 4.74s	remaining: 36.8s
# 114:	learn: 0.5198124	total: 4.75s	remaining: 36.6s
# 115:	learn: 0.5196189	total: 4.78s	remaining: 36.5s
# 116:	learn: 0.5195223	total: 4.82s	remaining: 36.3s
# 117:	learn: 0.5194198	total: 4.85s	remaining: 36.3s
# 118:	learn: 0.5192084	total: 4.88s	remaining: 36.2s
# 119:	learn: 0.5190743	total: 4.92s	remaining: 36.1s
# 120:	learn: 0.5189248	total: 4.96s	remaining: 36.1s
# 121:	learn: 0.5187436	total: 5s	remaining: 36s
# 122:	learn: 0.5186341	total: 5.03s	remaining: 35.9s
# 123:	learn: 0.5185287	total: 5.07s	remaining: 35.8s
# 124:	learn: 0.5184845	total: 5.1s	remaining: 35.7s
# 125:	learn: 0.5183567	total: 5.21s	remaining: 36.1s
# 126:	learn: 0.5182686	total: 5.24s	remaining: 36s
# 127:	learn: 0.5181598	total: 5.28s	remaining: 36s
# 128:	learn: 0.5179822	total: 5.31s	remaining: 35.9s
# 129:	learn: 0.5177326	total: 5.35s	remaining: 35.8s
# 130:	learn: 0.5174165	total: 5.38s	remaining: 35.7s
# 131:	learn: 0.5172625	total: 5.42s	remaining: 35.6s
# 132:	learn: 0.5172271	total: 5.45s	remaining: 35.5s
# 133:	learn: 0.5170814	total: 5.49s	remaining: 35.5s
# 134:	learn: 0.5169534	total: 5.52s	remaining: 35.4s
# 135:	learn: 0.5168803	total: 5.56s	remaining: 35.3s
# 136:	learn: 0.5168787	total: 5.57s	remaining: 35.1s
# 137:	learn: 0.5167536	total: 5.6s	remaining: 35s
# 138:	learn: 0.5166632	total: 5.64s	remaining: 35s
# 139:	learn: 0.5166404	total: 5.68s	remaining: 34.9s
# 140:	learn: 0.5165759	total: 5.71s	remaining: 34.8s
# 141:	learn: 0.5164099	total: 5.75s	remaining: 34.7s
# 142:	learn: 0.5161651	total: 5.83s	remaining: 34.9s
# 143:	learn: 0.5160161	total: 5.86s	remaining: 34.9s
# 144:	learn: 0.5158643	total: 5.9s	remaining: 34.8s
# 145:	learn: 0.5157209	total: 5.93s	remaining: 34.7s
# 146:	learn: 0.5155818	total: 5.97s	remaining: 34.7s
# 147:	learn: 0.5154385	total: 6.01s	remaining: 34.6s
# 148:	learn: 0.5153816	total: 6.04s	remaining: 34.5s
# 149:	learn: 0.5152666	total: 6.08s	remaining: 34.5s
# 150:	learn: 0.5151873	total: 6.12s	remaining: 34.4s
# 151:	learn: 0.5150998	total: 6.17s	remaining: 34.4s
# 152:	learn: 0.5149683	total: 6.21s	remaining: 34.4s
# 153:	learn: 0.5148036	total: 6.25s	remaining: 34.3s
# 154:	learn: 0.5146311	total: 6.28s	remaining: 34.2s
# 155:	learn: 0.5145616	total: 6.31s	remaining: 34.2s
# 156:	learn: 0.5144136	total: 6.35s	remaining: 34.1s
# 157:	learn: 0.5141894	total: 6.38s	remaining: 34s
# 158:	learn: 0.5141650	total: 6.42s	remaining: 33.9s
# 159:	learn: 0.5139559	total: 6.45s	remaining: 33.9s
# 160:	learn: 0.5136774	total: 6.49s	remaining: 33.8s
# 161:	learn: 0.5136599	total: 6.52s	remaining: 33.7s
# 162:	learn: 0.5135192	total: 6.56s	remaining: 33.7s
# 163:	learn: 0.5134065	total: 6.59s	remaining: 33.6s
# 164:	learn: 0.5132573	total: 6.63s	remaining: 33.5s
# 165:	learn: 0.5131412	total: 6.66s	remaining: 33.5s
# 166:	learn: 0.5130739	total: 6.7s	remaining: 33.4s
# 167:	learn: 0.5128379	total: 6.73s	remaining: 33.4s
# 168:	learn: 0.5126593	total: 6.77s	remaining: 33.3s
# 169:	learn: 0.5125544	total: 6.81s	remaining: 33.2s
# 170:	learn: 0.5123653	total: 6.84s	remaining: 33.2s
# 171:	learn: 0.5122710	total: 6.88s	remaining: 33.1s
# 172:	learn: 0.5121028	total: 7s	remaining: 33.4s
# 173:	learn: 0.5119875	total: 7.03s	remaining: 33.4s
# 174:	learn: 0.5118536	total: 7.07s	remaining: 33.3s
# 175:	learn: 0.5116877	total: 7.1s	remaining: 33.3s
# 176:	learn: 0.5115850	total: 7.14s	remaining: 33.2s
# 177:	learn: 0.5114030	total: 7.18s	remaining: 33.2s
# 178:	learn: 0.5112539	total: 7.25s	remaining: 33.2s
# 179:	learn: 0.5112383	total: 7.28s	remaining: 33.2s
# 180:	learn: 0.5110665	total: 7.32s	remaining: 33.1s
# 181:	learn: 0.5108774	total: 7.35s	remaining: 33s
# 182:	learn: 0.5106970	total: 7.39s	remaining: 33s
# 183:	learn: 0.5106507	total: 7.42s	remaining: 32.9s
# 184:	learn: 0.5106025	total: 7.46s	remaining: 32.9s
# 185:	learn: 0.5104923	total: 7.5s	remaining: 32.8s
# 186:	learn: 0.5102830	total: 7.54s	remaining: 32.8s
# 187:	learn: 0.5101066	total: 7.57s	remaining: 32.7s
# 188:	learn: 0.5099449	total: 7.61s	remaining: 32.6s
# 189:	learn: 0.5098603	total: 7.64s	remaining: 32.6s
# 190:	learn: 0.5097216	total: 7.67s	remaining: 32.5s
# 191:	learn: 0.5095414	total: 7.71s	remaining: 32.4s
# 192:	learn: 0.5094190	total: 7.75s	remaining: 32.4s
# 193:	learn: 0.5093364	total: 7.78s	remaining: 32.3s
# 194:	learn: 0.5092105	total: 7.82s	remaining: 32.3s
# 195:	learn: 0.5091014	total: 7.86s	remaining: 32.2s
# 196:	learn: 0.5090047	total: 7.89s	remaining: 32.2s
# 197:	learn: 0.5089001	total: 7.93s	remaining: 32.1s
# 198:	learn: 0.5087653	total: 8s	remaining: 32.2s
# 199:	learn: 0.5085175	total: 8.03s	remaining: 32.1s
# 200:	learn: 0.5083478	total: 8.06s	remaining: 32.1s
# 201:	learn: 0.5082641	total: 8.14s	remaining: 32.2s
# 202:	learn: 0.5080140	total: 8.18s	remaining: 32.1s
# 203:	learn: 0.5079007	total: 8.27s	remaining: 32.3s
# 204:	learn: 0.5078200	total: 8.31s	remaining: 32.2s
# 205:	learn: 0.5077175	total: 8.35s	remaining: 32.2s
# 206:	learn: 0.5075720	total: 8.44s	remaining: 32.3s
# 207:	learn: 0.5075081	total: 8.47s	remaining: 32.3s
# 208:	learn: 0.5072487	total: 8.51s	remaining: 32.2s
# 209:	learn: 0.5071449	total: 8.54s	remaining: 32.1s
# 210:	learn: 0.5070429	total: 8.65s	remaining: 32.4s
# 211:	learn: 0.5069673	total: 8.69s	remaining: 32.3s
# 212:	learn: 0.5067348	total: 8.72s	remaining: 32.2s
# 213:	learn: 0.5066396	total: 8.76s	remaining: 32.2s
# 214:	learn: 0.5064779	total: 8.79s	remaining: 32.1s
# 215:	learn: 0.5062709	total: 8.83s	remaining: 32s
# 216:	learn: 0.5062349	total: 8.86s	remaining: 32s
# 217:	learn: 0.5060069	total: 8.9s	remaining: 31.9s
# 218:	learn: 0.5058490	total: 8.93s	remaining: 31.9s
# 219:	learn: 0.5057605	total: 8.96s	remaining: 31.8s
# 220:	learn: 0.5057167	total: 9s	remaining: 31.7s
# 221:	learn: 0.5055045	total: 9.03s	remaining: 31.7s
# 222:	learn: 0.5054331	total: 9.07s	remaining: 31.6s
# 223:	learn: 0.5053077	total: 9.11s	remaining: 31.5s
# 224:	learn: 0.5051696	total: 9.14s	remaining: 31.5s
# 225:	learn: 0.5049254	total: 9.18s	remaining: 31.4s
# 226:	learn: 0.5047283	total: 9.21s	remaining: 31.4s
# 227:	learn: 0.5046510	total: 9.25s	remaining: 31.3s
# 228:	learn: 0.5045506	total: 9.29s	remaining: 31.3s
# 229:	learn: 0.5044383	total: 9.32s	remaining: 31.2s
# 230:	learn: 0.5044192	total: 9.36s	remaining: 31.2s
# 231:	learn: 0.5042049	total: 9.39s	remaining: 31.1s
# 232:	learn: 0.5039742	total: 9.43s	remaining: 31.1s
# 233:	learn: 0.5039338	total: 9.46s	remaining: 31s
# 234:	learn: 0.5038726	total: 9.5s	remaining: 30.9s
# 235:	learn: 0.5038561	total: 9.54s	remaining: 30.9s
# 236:	learn: 0.5037158	total: 9.57s	remaining: 30.8s
# 237:	learn: 0.5036795	total: 9.61s	remaining: 30.8s
# 238:	learn: 0.5035471	total: 9.64s	remaining: 30.7s
# 239:	learn: 0.5033469	total: 9.68s	remaining: 30.7s
# 240:	learn: 0.5032697	total: 9.72s	remaining: 30.6s
# 241:	learn: 0.5031554	total: 9.75s	remaining: 30.5s
# 242:	learn: 0.5030626	total: 9.79s	remaining: 30.5s
# 243:	learn: 0.5028332	total: 9.83s	remaining: 30.4s
# 244:	learn: 0.5027366	total: 9.86s	remaining: 30.4s
# 245:	learn: 0.5026907	total: 9.9s	remaining: 30.3s
# 246:	learn: 0.5025448	total: 9.93s	remaining: 30.3s
# 247:	learn: 0.5024701	total: 9.97s	remaining: 30.2s
# 248:	learn: 0.5024351	total: 10s	remaining: 30.2s
# 249:	learn: 0.5023653	total: 10s	remaining: 30.1s
# 250:	learn: 0.5023224	total: 10.1s	remaining: 30.1s
# 251:	learn: 0.5022642	total: 10.1s	remaining: 30s
# 252:	learn: 0.5021392	total: 10.1s	remaining: 30s
# 253:	learn: 0.5019937	total: 10.2s	remaining: 29.9s
# 254:	learn: 0.5018978	total: 10.2s	remaining: 29.9s
# 255:	learn: 0.5018043	total: 10.3s	remaining: 29.8s
# 256:	learn: 0.5017001	total: 10.3s	remaining: 29.8s
# 257:	learn: 0.5016699	total: 10.3s	remaining: 29.7s
# 258:	learn: 0.5015906	total: 10.4s	remaining: 29.7s
# 259:	learn: 0.5015356	total: 10.4s	remaining: 29.6s
# 260:	learn: 0.5015268	total: 10.4s	remaining: 29.5s
# 261:	learn: 0.5014635	total: 10.5s	remaining: 29.5s
# 262:	learn: 0.5012319	total: 10.5s	remaining: 29.4s
# 263:	learn: 0.5011600	total: 10.5s	remaining: 29.4s
# 264:	learn: 0.5010942	total: 10.6s	remaining: 29.3s
# 265:	learn: 0.5009499	total: 10.6s	remaining: 29.3s
# 266:	learn: 0.5008802	total: 10.6s	remaining: 29.2s
# 267:	learn: 0.5007860	total: 10.7s	remaining: 29.2s
# 268:	learn: 0.5005368	total: 10.7s	remaining: 29.1s
# 269:	learn: 0.5004591	total: 10.8s	remaining: 29.1s
# 270:	learn: 0.5003745	total: 10.8s	remaining: 29s
# 271:	learn: 0.5002906	total: 10.9s	remaining: 29s
# 272:	learn: 0.5000607	total: 10.9s	remaining: 29s
# 273:	learn: 0.4999444	total: 10.9s	remaining: 28.9s
# 274:	learn: 0.4998457	total: 11s	remaining: 28.9s
# 275:	learn: 0.4997090	total: 11s	remaining: 28.8s
# 276:	learn: 0.4996312	total: 11s	remaining: 28.8s
# 277:	learn: 0.4996302	total: 11.1s	remaining: 28.7s
# 278:	learn: 0.4995274	total: 11.1s	remaining: 28.7s
# 279:	learn: 0.4993953	total: 11.1s	remaining: 28.6s
# 280:	learn: 0.4991761	total: 11.2s	remaining: 28.6s
# 281:	learn: 0.4990976	total: 11.2s	remaining: 28.5s
# 282:	learn: 0.4989845	total: 11.2s	remaining: 28.5s
# 283:	learn: 0.4988934	total: 11.3s	remaining: 28.4s
# 284:	learn: 0.4988095	total: 11.3s	remaining: 28.4s
# 285:	learn: 0.4987424	total: 11.3s	remaining: 28.3s
# 286:	learn: 0.4986173	total: 11.4s	remaining: 28.3s
# 287:	learn: 0.4985100	total: 11.4s	remaining: 28.2s
# 288:	learn: 0.4984275	total: 11.5s	remaining: 28.2s
# 289:	learn: 0.4982254	total: 11.5s	remaining: 28.1s
# 290:	learn: 0.4981768	total: 11.5s	remaining: 28.1s
# 291:	learn: 0.4980479	total: 11.6s	remaining: 28s
# 292:	learn: 0.4980031	total: 11.6s	remaining: 28s
# 293:	learn: 0.4979118	total: 11.6s	remaining: 27.9s
# 294:	learn: 0.4979034	total: 11.7s	remaining: 27.9s
# 295:	learn: 0.4977404	total: 11.7s	remaining: 27.8s
# 296:	learn: 0.4976414	total: 11.7s	remaining: 27.8s
# 297:	learn: 0.4975384	total: 11.8s	remaining: 27.7s
# 298:	learn: 0.4974522	total: 11.8s	remaining: 27.7s
# 299:	learn: 0.4973747	total: 11.8s	remaining: 27.6s
# 300:	learn: 0.4972307	total: 11.9s	remaining: 27.6s
# 301:	learn: 0.4970610	total: 11.9s	remaining: 27.6s
# 302:	learn: 0.4968926	total: 12s	remaining: 27.5s
# 303:	learn: 0.4967563	total: 12s	remaining: 27.5s
# 304:	learn: 0.4967005	total: 12s	remaining: 27.4s
# 305:	learn: 0.4966574	total: 12.1s	remaining: 27.4s
# 306:	learn: 0.4966039	total: 12.1s	remaining: 27.4s
# 307:	learn: 0.4965908	total: 12.2s	remaining: 27.3s
# 308:	learn: 0.4965495	total: 12.2s	remaining: 27.3s
# 309:	learn: 0.4963951	total: 12.2s	remaining: 27.2s
# 310:	learn: 0.4963591	total: 12.3s	remaining: 27.2s
# 311:	learn: 0.4962286	total: 12.3s	remaining: 27.1s
# 312:	learn: 0.4961581	total: 12.3s	remaining: 27.1s
# 313:	learn: 0.4961102	total: 12.4s	remaining: 27s
# 314:	learn: 0.4960822	total: 12.4s	remaining: 27s
# 315:	learn: 0.4959720	total: 12.4s	remaining: 26.9s
# 316:	learn: 0.4957961	total: 12.5s	remaining: 26.9s
# 317:	learn: 0.4956668	total: 12.5s	remaining: 26.8s
# 318:	learn: 0.4956052	total: 12.5s	remaining: 26.8s
# 319:	learn: 0.4955169	total: 12.6s	remaining: 26.7s
# 320:	learn: 0.4953726	total: 12.6s	remaining: 26.7s
# 321:	learn: 0.4953216	total: 12.7s	remaining: 26.7s
# 322:	learn: 0.4952717	total: 12.7s	remaining: 26.7s
# 323:	learn: 0.4951709	total: 12.8s	remaining: 26.6s
# 324:	learn: 0.4950729	total: 12.8s	remaining: 26.6s
# 325:	learn: 0.4949646	total: 12.8s	remaining: 26.5s
# 326:	learn: 0.4949135	total: 12.9s	remaining: 26.5s
# 327:	learn: 0.4947785	total: 12.9s	remaining: 26.5s
# 328:	learn: 0.4947012	total: 12.9s	remaining: 26.4s
# 329:	learn: 0.4945856	total: 13s	remaining: 26.4s
# 330:	learn: 0.4945223	total: 13s	remaining: 26.3s
# 331:	learn: 0.4944428	total: 13.1s	remaining: 26.3s
# 332:	learn: 0.4943823	total: 13.1s	remaining: 26.3s
# 333:	learn: 0.4943100	total: 13.2s	remaining: 26.2s
# 334:	learn: 0.4940960	total: 13.2s	remaining: 26.2s
# 335:	learn: 0.4940465	total: 13.2s	remaining: 26.1s
# 336:	learn: 0.4939766	total: 13.3s	remaining: 26.1s
# 337:	learn: 0.4938314	total: 13.3s	remaining: 26s
# 338:	learn: 0.4936857	total: 13.3s	remaining: 26s
# 339:	learn: 0.4936459	total: 13.4s	remaining: 26s
# 340:	learn: 0.4936237	total: 13.4s	remaining: 25.9s
# 341:	learn: 0.4934993	total: 13.4s	remaining: 25.9s
# 342:	learn: 0.4934431	total: 13.5s	remaining: 25.8s
# 343:	learn: 0.4934009	total: 13.5s	remaining: 25.8s
# 344:	learn: 0.4932974	total: 13.6s	remaining: 25.7s
# 345:	learn: 0.4932503	total: 13.6s	remaining: 25.7s
# 346:	learn: 0.4931484	total: 13.6s	remaining: 25.6s
# 347:	learn: 0.4930536	total: 13.7s	remaining: 25.6s
# 348:	learn: 0.4929664	total: 13.7s	remaining: 25.5s
# 349:	learn: 0.4929114	total: 13.7s	remaining: 25.5s
# 350:	learn: 0.4927827	total: 13.8s	remaining: 25.4s
# 351:	learn: 0.4926749	total: 13.8s	remaining: 25.4s
# 352:	learn: 0.4925829	total: 13.8s	remaining: 25.4s
# 353:	learn: 0.4924765	total: 13.9s	remaining: 25.3s
# 354:	learn: 0.4924398	total: 13.9s	remaining: 25.3s
# 355:	learn: 0.4923597	total: 13.9s	remaining: 25.2s
# 356:	learn: 0.4922265	total: 14s	remaining: 25.2s
# 357:	learn: 0.4920915	total: 14s	remaining: 25.1s
# 358:	learn: 0.4919889	total: 14.1s	remaining: 25.1s
# 359:	learn: 0.4919748	total: 14.1s	remaining: 25s
# 360:	learn: 0.4919369	total: 14.1s	remaining: 25s
# 361:	learn: 0.4918279	total: 14.2s	remaining: 24.9s
# 362:	learn: 0.4917120	total: 14.2s	remaining: 24.9s
# 363:	learn: 0.4916216	total: 14.2s	remaining: 24.9s
# 364:	learn: 0.4915734	total: 14.3s	remaining: 24.8s
# 365:	learn: 0.4914723	total: 14.3s	remaining: 24.8s
# 366:	learn: 0.4914185	total: 14.3s	remaining: 24.7s
# 367:	learn: 0.4913544	total: 14.4s	remaining: 24.7s
# 368:	learn: 0.4913115	total: 14.4s	remaining: 24.6s
# 369:	learn: 0.4912502	total: 14.4s	remaining: 24.6s
# 370:	learn: 0.4911779	total: 14.5s	remaining: 24.6s
# 371:	learn: 0.4909930	total: 14.6s	remaining: 24.6s
# 372:	learn: 0.4908537	total: 14.6s	remaining: 24.5s
# 373:	learn: 0.4907806	total: 14.6s	remaining: 24.5s
# 374:	learn: 0.4907477	total: 14.7s	remaining: 24.4s
# 375:	learn: 0.4906370	total: 14.7s	remaining: 24.4s
# 376:	learn: 0.4904497	total: 14.7s	remaining: 24.4s
# 377:	learn: 0.4904424	total: 14.8s	remaining: 24.3s
# 378:	learn: 0.4903887	total: 14.8s	remaining: 24.3s
# 379:	learn: 0.4903769	total: 14.9s	remaining: 24.3s
# 380:	learn: 0.4903018	total: 14.9s	remaining: 24.2s
# 381:	learn: 0.4901578	total: 14.9s	remaining: 24.2s
# 382:	learn: 0.4900818	total: 15s	remaining: 24.2s
# 383:	learn: 0.4899982	total: 15s	remaining: 24.1s
# 384:	learn: 0.4898380	total: 15.1s	remaining: 24.1s
# 385:	learn: 0.4897798	total: 15.1s	remaining: 24s
# 386:	learn: 0.4896470	total: 15.1s	remaining: 24s
# 387:	learn: 0.4895722	total: 15.2s	remaining: 23.9s
# 388:	learn: 0.4895620	total: 15.2s	remaining: 23.9s
# 389:	learn: 0.4894439	total: 15.3s	remaining: 23.9s
# 390:	learn: 0.4894006	total: 15.3s	remaining: 23.8s
# 391:	learn: 0.4892738	total: 15.3s	remaining: 23.8s
# 392:	learn: 0.4892157	total: 15.4s	remaining: 23.7s
# 393:	learn: 0.4892050	total: 15.4s	remaining: 23.7s
# 394:	learn: 0.4890037	total: 15.4s	remaining: 23.6s
# 395:	learn: 0.4889416	total: 15.5s	remaining: 23.6s
# 396:	learn: 0.4888772	total: 15.5s	remaining: 23.5s
# 397:	learn: 0.4887322	total: 15.5s	remaining: 23.5s
# 398:	learn: 0.4886492	total: 15.6s	remaining: 23.5s
# 399:	learn: 0.4885926	total: 15.6s	remaining: 23.4s
# 400:	learn: 0.4884670	total: 15.6s	remaining: 23.4s
# 401:	learn: 0.4884405	total: 15.7s	remaining: 23.3s
# 402:	learn: 0.4884013	total: 15.7s	remaining: 23.3s
# 403:	learn: 0.4882952	total: 15.7s	remaining: 23.2s
# 404:	learn: 0.4882668	total: 15.8s	remaining: 23.2s
# 405:	learn: 0.4881537	total: 15.8s	remaining: 23.1s
# 406:	learn: 0.4880122	total: 15.9s	remaining: 23.1s
# 407:	learn: 0.4879739	total: 15.9s	remaining: 23.1s
# 408:	learn: 0.4879468	total: 15.9s	remaining: 23s
# 409:	learn: 0.4879453	total: 16s	remaining: 23s
# 410:	learn: 0.4878716	total: 16s	remaining: 22.9s
# 411:	learn: 0.4876711	total: 16s	remaining: 22.9s
# 412:	learn: 0.4875348	total: 16.1s	remaining: 22.8s
# 413:	learn: 0.4874301	total: 16.1s	remaining: 22.8s
# 414:	learn: 0.4873303	total: 16.1s	remaining: 22.7s
# 415:	learn: 0.4872734	total: 16.2s	remaining: 22.7s
# 416:	learn: 0.4872149	total: 16.2s	remaining: 22.7s
# 417:	learn: 0.4871292	total: 16.2s	remaining: 22.6s
# 418:	learn: 0.4870548	total: 16.3s	remaining: 22.6s
# 419:	learn: 0.4868819	total: 16.3s	remaining: 22.5s
# 420:	learn: 0.4867644	total: 16.3s	remaining: 22.5s
# 421:	learn: 0.4866704	total: 16.4s	remaining: 22.4s
# 422:	learn: 0.4865820	total: 16.4s	remaining: 22.4s
# 423:	learn: 0.4864766	total: 16.5s	remaining: 22.4s
# 424:	learn: 0.4862481	total: 16.5s	remaining: 22.3s
# 425:	learn: 0.4860947	total: 16.5s	remaining: 22.3s
# 426:	learn: 0.4860231	total: 16.6s	remaining: 22.2s
# 427:	learn: 0.4859216	total: 16.6s	remaining: 22.2s
# 428:	learn: 0.4857853	total: 16.6s	remaining: 22.1s
# 429:	learn: 0.4856216	total: 16.7s	remaining: 22.1s
# 430:	learn: 0.4855188	total: 16.7s	remaining: 22.1s
# 431:	learn: 0.4854288	total: 16.7s	remaining: 22s
# 432:	learn: 0.4853087	total: 16.8s	remaining: 22s
# 433:	learn: 0.4852429	total: 16.8s	remaining: 21.9s
# 434:	learn: 0.4851387	total: 16.9s	remaining: 21.9s
# 435:	learn: 0.4850516	total: 16.9s	remaining: 21.8s
# 436:	learn: 0.4849916	total: 16.9s	remaining: 21.8s
# 437:	learn: 0.4848790	total: 17s	remaining: 21.8s
# 438:	learn: 0.4848694	total: 17s	remaining: 21.7s
# 439:	learn: 0.4847915	total: 17s	remaining: 21.7s
# 440:	learn: 0.4847575	total: 17.1s	remaining: 21.6s
# 441:	learn: 0.4846524	total: 17.1s	remaining: 21.6s
# 442:	learn: 0.4845480	total: 17.2s	remaining: 21.6s
# 443:	learn: 0.4843737	total: 17.2s	remaining: 21.5s
# 444:	learn: 0.4841797	total: 17.2s	remaining: 21.5s
# 445:	learn: 0.4840626	total: 17.3s	remaining: 21.4s
# 446:	learn: 0.4839082	total: 17.3s	remaining: 21.4s
# 447:	learn: 0.4838520	total: 17.3s	remaining: 21.4s
# 448:	learn: 0.4838261	total: 17.4s	remaining: 21.3s
# 449:	learn: 0.4837911	total: 17.4s	remaining: 21.3s
# 450:	learn: 0.4836677	total: 17.4s	remaining: 21.2s
# 451:	learn: 0.4835668	total: 17.5s	remaining: 21.2s
# 452:	learn: 0.4835406	total: 17.5s	remaining: 21.1s
# 453:	learn: 0.4834594	total: 17.5s	remaining: 21.1s
# 454:	learn: 0.4833670	total: 17.6s	remaining: 21.1s
# 455:	learn: 0.4833114	total: 17.6s	remaining: 21s
# 456:	learn: 0.4833063	total: 17.7s	remaining: 21s
# 457:	learn: 0.4832248	total: 17.7s	remaining: 20.9s
# 458:	learn: 0.4831834	total: 17.7s	remaining: 20.9s
# 459:	learn: 0.4831098	total: 17.8s	remaining: 20.8s
# 460:	learn: 0.4830311	total: 17.8s	remaining: 20.8s
# 461:	learn: 0.4829769	total: 17.8s	remaining: 20.8s
# 462:	learn: 0.4828278	total: 17.9s	remaining: 20.7s
# 463:	learn: 0.4827560	total: 17.9s	remaining: 20.7s
# 464:	learn: 0.4827311	total: 17.9s	remaining: 20.6s
# 465:	learn: 0.4825692	total: 18s	remaining: 20.6s
# 466:	learn: 0.4825163	total: 18s	remaining: 20.6s
# 467:	learn: 0.4823976	total: 18s	remaining: 20.5s
# 468:	learn: 0.4822168	total: 18.1s	remaining: 20.5s
# 469:	learn: 0.4821621	total: 18.1s	remaining: 20.4s
# 470:	learn: 0.4820208	total: 18.1s	remaining: 20.4s
# 471:	learn: 0.4820193	total: 18.2s	remaining: 20.3s
# 472:	learn: 0.4818933	total: 18.2s	remaining: 20.3s
# 473:	learn: 0.4818007	total: 18.3s	remaining: 20.3s
# 474:	learn: 0.4817025	total: 18.3s	remaining: 20.2s
# 475:	learn: 0.4816233	total: 18.3s	remaining: 20.2s
# 476:	learn: 0.4815741	total: 18.4s	remaining: 20.1s
# 477:	learn: 0.4814792	total: 18.4s	remaining: 20.1s
# 478:	learn: 0.4814610	total: 18.5s	remaining: 20.1s
# 479:	learn: 0.4814464	total: 18.5s	remaining: 20.1s
# 480:	learn: 0.4813895	total: 18.6s	remaining: 20s
# 481:	learn: 0.4812377	total: 18.6s	remaining: 20s
# 482:	learn: 0.4811975	total: 18.6s	remaining: 19.9s
# 483:	learn: 0.4811273	total: 18.7s	remaining: 19.9s
# 484:	learn: 0.4810441	total: 18.7s	remaining: 19.9s
# 485:	learn: 0.4809666	total: 18.7s	remaining: 19.8s
# 486:	learn: 0.4809237	total: 18.8s	remaining: 19.8s
# 487:	learn: 0.4808903	total: 18.8s	remaining: 19.7s
# 488:	learn: 0.4807269	total: 18.8s	remaining: 19.7s
# 489:	learn: 0.4806693	total: 18.9s	remaining: 19.7s
# 490:	learn: 0.4806054	total: 18.9s	remaining: 19.6s
# 491:	learn: 0.4805281	total: 19s	remaining: 19.6s
# 492:	learn: 0.4804159	total: 19s	remaining: 19.5s
# 493:	learn: 0.4803465	total: 19.1s	remaining: 19.6s
# 494:	learn: 0.4802653	total: 19.1s	remaining: 19.5s
# 495:	learn: 0.4801966	total: 19.2s	remaining: 19.5s
# 496:	learn: 0.4801457	total: 19.2s	remaining: 19.4s
# 497:	learn: 0.4800056	total: 19.2s	remaining: 19.4s
# 498:	learn: 0.4799599	total: 19.3s	remaining: 19.3s
# 499:	learn: 0.4798151	total: 19.4s	remaining: 19.4s
# 500:	learn: 0.4797596	total: 19.4s	remaining: 19.3s
# 501:	learn: 0.4797133	total: 19.4s	remaining: 19.3s
# 502:	learn: 0.4796142	total: 19.5s	remaining: 19.2s
# 503:	learn: 0.4795302	total: 19.5s	remaining: 19.2s
# 504:	learn: 0.4794644	total: 19.5s	remaining: 19.1s
# 505:	learn: 0.4793438	total: 19.6s	remaining: 19.1s
# 506:	learn: 0.4792333	total: 19.6s	remaining: 19.1s
# 507:	learn: 0.4792308	total: 19.6s	remaining: 19s
# 508:	learn: 0.4792121	total: 19.7s	remaining: 19s
# 509:	learn: 0.4791586	total: 19.7s	remaining: 18.9s
# 510:	learn: 0.4791024	total: 19.8s	remaining: 18.9s
# 511:	learn: 0.4790317	total: 19.8s	remaining: 18.9s
# 512:	learn: 0.4788883	total: 19.8s	remaining: 18.8s
# 513:	learn: 0.4788327	total: 19.9s	remaining: 18.8s
# 514:	learn: 0.4787158	total: 19.9s	remaining: 18.7s
# 515:	learn: 0.4786625	total: 19.9s	remaining: 18.7s
# 516:	learn: 0.4786533	total: 20s	remaining: 18.6s
# 517:	learn: 0.4786178	total: 20s	remaining: 18.6s
# 518:	learn: 0.4785662	total: 20s	remaining: 18.6s
# 519:	learn: 0.4785002	total: 20.1s	remaining: 18.5s
# 520:	learn: 0.4784323	total: 20.1s	remaining: 18.5s
# 521:	learn: 0.4783257	total: 20.1s	remaining: 18.4s
# 522:	learn: 0.4782518	total: 20.2s	remaining: 18.4s
# 523:	learn: 0.4781728	total: 20.2s	remaining: 18.4s
# 524:	learn: 0.4781209	total: 20.3s	remaining: 18.3s
# 525:	learn: 0.4780128	total: 20.3s	remaining: 18.3s
# 526:	learn: 0.4779397	total: 20.3s	remaining: 18.2s
# 527:	learn: 0.4778958	total: 20.4s	remaining: 18.2s
# 528:	learn: 0.4778244	total: 20.4s	remaining: 18.2s
# 529:	learn: 0.4777893	total: 20.4s	remaining: 18.1s
# 530:	learn: 0.4777148	total: 20.5s	remaining: 18.1s
# 531:	learn: 0.4775839	total: 20.6s	remaining: 18.1s
# 532:	learn: 0.4774997	total: 20.6s	remaining: 18.1s
# 533:	learn: 0.4774906	total: 20.6s	remaining: 18s
# 534:	learn: 0.4774077	total: 20.7s	remaining: 18s
# 535:	learn: 0.4773427	total: 20.8s	remaining: 18s
# 536:	learn: 0.4772339	total: 20.8s	remaining: 17.9s
# 537:	learn: 0.4771439	total: 20.9s	remaining: 17.9s
# 538:	learn: 0.4769652	total: 20.9s	remaining: 17.9s
# 539:	learn: 0.4769150	total: 20.9s	remaining: 17.8s
# 540:	learn: 0.4767808	total: 21s	remaining: 17.8s
# 541:	learn: 0.4766803	total: 21.1s	remaining: 17.8s
# 542:	learn: 0.4766318	total: 21.1s	remaining: 17.7s
# 543:	learn: 0.4765475	total: 21.1s	remaining: 17.7s
# 544:	learn: 0.4764855	total: 21.2s	remaining: 17.7s
# 545:	learn: 0.4763853	total: 21.2s	remaining: 17.6s
# 546:	learn: 0.4762522	total: 21.2s	remaining: 17.6s
# 547:	learn: 0.4761838	total: 21.3s	remaining: 17.5s
# 548:	learn: 0.4761181	total: 21.3s	remaining: 17.5s
# 549:	learn: 0.4759959	total: 21.3s	remaining: 17.5s
# 550:	learn: 0.4759221	total: 21.4s	remaining: 17.4s
# 551:	learn: 0.4758589	total: 21.4s	remaining: 17.4s
# 552:	learn: 0.4756830	total: 21.4s	remaining: 17.3s
# 553:	learn: 0.4755609	total: 21.5s	remaining: 17.3s
# 554:	learn: 0.4755592	total: 21.5s	remaining: 17.2s
# 555:	learn: 0.4755203	total: 21.5s	remaining: 17.2s
# 556:	learn: 0.4754516	total: 21.6s	remaining: 17.2s
# 557:	learn: 0.4753919	total: 21.7s	remaining: 17.2s
# 558:	learn: 0.4753029	total: 21.8s	remaining: 17.2s
# 559:	learn: 0.4751794	total: 21.8s	remaining: 17.1s
# 560:	learn: 0.4750500	total: 21.8s	remaining: 17.1s
# 561:	learn: 0.4750139	total: 21.9s	remaining: 17s
# 562:	learn: 0.4748997	total: 21.9s	remaining: 17s
# 563:	learn: 0.4748395	total: 21.9s	remaining: 17s
# 564:	learn: 0.4747232	total: 22s	remaining: 16.9s
# 565:	learn: 0.4746836	total: 22s	remaining: 16.9s
# 566:	learn: 0.4745615	total: 22.1s	remaining: 16.8s
# 567:	learn: 0.4745131	total: 22.1s	remaining: 16.8s
# 568:	learn: 0.4743554	total: 22.1s	remaining: 16.8s
# 569:	learn: 0.4742374	total: 22.2s	remaining: 16.7s
# 570:	learn: 0.4741432	total: 22.2s	remaining: 16.7s
# 571:	learn: 0.4740718	total: 22.2s	remaining: 16.6s
# 572:	learn: 0.4740388	total: 22.3s	remaining: 16.6s
# 573:	learn: 0.4739613	total: 22.3s	remaining: 16.6s
# 574:	learn: 0.4738563	total: 22.3s	remaining: 16.5s
# 575:	learn: 0.4738090	total: 22.4s	remaining: 16.5s
# 576:	learn: 0.4736860	total: 22.4s	remaining: 16.4s
# 577:	learn: 0.4735170	total: 22.4s	remaining: 16.4s
# 578:	learn: 0.4733894	total: 22.5s	remaining: 16.3s
# 579:	learn: 0.4733418	total: 22.5s	remaining: 16.3s
# 580:	learn: 0.4731617	total: 22.6s	remaining: 16.3s
# 581:	learn: 0.4731083	total: 22.6s	remaining: 16.2s
# 582:	learn: 0.4730350	total: 22.6s	remaining: 16.2s
# 583:	learn: 0.4728664	total: 22.7s	remaining: 16.1s
# 584:	learn: 0.4727965	total: 22.7s	remaining: 16.1s
# 585:	learn: 0.4726681	total: 22.7s	remaining: 16.1s
# 586:	learn: 0.4725806	total: 22.8s	remaining: 16s
# 587:	learn: 0.4725320	total: 22.8s	remaining: 16s
# 588:	learn: 0.4724824	total: 22.8s	remaining: 15.9s
# 589:	learn: 0.4724719	total: 22.9s	remaining: 15.9s
# 590:	learn: 0.4724640	total: 22.9s	remaining: 15.9s
# 591:	learn: 0.4724188	total: 22.9s	remaining: 15.8s
# 592:	learn: 0.4723151	total: 23s	remaining: 15.8s
# 593:	learn: 0.4722059	total: 23.1s	remaining: 15.8s
# 594:	learn: 0.4720696	total: 23.1s	remaining: 15.7s
# 595:	learn: 0.4719591	total: 23.1s	remaining: 15.7s
# 596:	learn: 0.4719054	total: 23.2s	remaining: 15.7s
# 597:	learn: 0.4717229	total: 23.2s	remaining: 15.6s
# 598:	learn: 0.4716096	total: 23.3s	remaining: 15.6s
# 599:	learn: 0.4715393	total: 23.3s	remaining: 15.5s
# 600:	learn: 0.4715066	total: 23.3s	remaining: 15.5s
# 601:	learn: 0.4714352	total: 23.4s	remaining: 15.5s
# 602:	learn: 0.4713406	total: 23.5s	remaining: 15.4s
# 603:	learn: 0.4712470	total: 23.5s	remaining: 15.4s
# 604:	learn: 0.4711542	total: 23.5s	remaining: 15.4s
# 605:	learn: 0.4711413	total: 23.6s	remaining: 15.4s
# 606:	learn: 0.4710366	total: 23.7s	remaining: 15.3s
# 607:	learn: 0.4709687	total: 23.7s	remaining: 15.3s
# 608:	learn: 0.4709308	total: 23.8s	remaining: 15.3s
# 609:	learn: 0.4708810	total: 23.8s	remaining: 15.2s
# 610:	learn: 0.4707930	total: 23.8s	remaining: 15.2s
# 611:	learn: 0.4707501	total: 23.9s	remaining: 15.1s
# 612:	learn: 0.4706722	total: 23.9s	remaining: 15.1s
# 613:	learn: 0.4705656	total: 23.9s	remaining: 15.1s
# 614:	learn: 0.4704735	total: 24s	remaining: 15s
# 615:	learn: 0.4704066	total: 24s	remaining: 15s
# 616:	learn: 0.4703156	total: 24s	remaining: 14.9s
# 617:	learn: 0.4702642	total: 24.1s	remaining: 14.9s
# 618:	learn: 0.4701861	total: 24.1s	remaining: 14.8s
# 619:	learn: 0.4701504	total: 24.1s	remaining: 14.8s
# 620:	learn: 0.4701245	total: 24.2s	remaining: 14.8s
# 621:	learn: 0.4700580	total: 24.2s	remaining: 14.7s
# 622:	learn: 0.4700031	total: 24.3s	remaining: 14.7s
# 623:	learn: 0.4699504	total: 24.3s	remaining: 14.7s
# 624:	learn: 0.4698773	total: 24.4s	remaining: 14.6s
# 625:	learn: 0.4698207	total: 24.4s	remaining: 14.6s
# 626:	learn: 0.4697510	total: 24.5s	remaining: 14.6s
# 627:	learn: 0.4696757	total: 24.5s	remaining: 14.5s
# 628:	learn: 0.4695478	total: 24.5s	remaining: 14.5s
# 629:	learn: 0.4695100	total: 24.6s	remaining: 14.4s
# 630:	learn: 0.4695046	total: 24.6s	remaining: 14.4s
# 631:	learn: 0.4693988	total: 24.7s	remaining: 14.4s
# 632:	learn: 0.4693203	total: 24.7s	remaining: 14.3s
# 633:	learn: 0.4692459	total: 24.7s	remaining: 14.3s
# 634:	learn: 0.4691694	total: 24.8s	remaining: 14.2s
# 635:	learn: 0.4690624	total: 24.8s	remaining: 14.2s
# 636:	learn: 0.4690610	total: 24.9s	remaining: 14.2s
# 637:	learn: 0.4689392	total: 24.9s	remaining: 14.1s
# 638:	learn: 0.4688915	total: 24.9s	remaining: 14.1s
# 639:	learn: 0.4688875	total: 25s	remaining: 14.1s
# 640:	learn: 0.4688238	total: 25s	remaining: 14s
# 641:	learn: 0.4687391	total: 25.1s	remaining: 14s
# 642:	learn: 0.4686827	total: 25.1s	remaining: 13.9s
# 643:	learn: 0.4685716	total: 25.1s	remaining: 13.9s
# 644:	learn: 0.4685248	total: 25.2s	remaining: 13.9s
# 645:	learn: 0.4684417	total: 25.3s	remaining: 13.8s
# 646:	learn: 0.4683715	total: 25.3s	remaining: 13.8s
# 647:	learn: 0.4683193	total: 25.4s	remaining: 13.8s
# 648:	learn: 0.4682771	total: 25.4s	remaining: 13.7s
# 649:	learn: 0.4682571	total: 25.4s	remaining: 13.7s
# 650:	learn: 0.4682531	total: 25.4s	remaining: 13.6s
# 651:	learn: 0.4681350	total: 25.5s	remaining: 13.6s
# 652:	learn: 0.4680468	total: 25.5s	remaining: 13.6s
# 653:	learn: 0.4680441	total: 25.5s	remaining: 13.5s
# 654:	learn: 0.4679170	total: 25.6s	remaining: 13.5s
# 655:	learn: 0.4678696	total: 25.6s	remaining: 13.4s
# 656:	learn: 0.4678223	total: 25.6s	remaining: 13.4s
# 657:	learn: 0.4677206	total: 25.7s	remaining: 13.3s
# 658:	learn: 0.4676673	total: 25.7s	remaining: 13.3s
# 659:	learn: 0.4675157	total: 25.8s	remaining: 13.3s
# 660:	learn: 0.4673736	total: 25.8s	remaining: 13.2s
# 661:	learn: 0.4673057	total: 25.8s	remaining: 13.2s
# 662:	learn: 0.4672675	total: 25.9s	remaining: 13.1s
# 663:	learn: 0.4672154	total: 25.9s	remaining: 13.1s
# 664:	learn: 0.4670555	total: 25.9s	remaining: 13.1s
# 665:	learn: 0.4670145	total: 26s	remaining: 13s
# 666:	learn: 0.4669179	total: 26s	remaining: 13s
# 667:	learn: 0.4668615	total: 26s	remaining: 12.9s
# 668:	learn: 0.4667557	total: 26.1s	remaining: 12.9s
# 669:	learn: 0.4667540	total: 26.1s	remaining: 12.9s
# 670:	learn: 0.4667206	total: 26.1s	remaining: 12.8s
# 671:	learn: 0.4666395	total: 26.2s	remaining: 12.8s
# 672:	learn: 0.4665746	total: 26.2s	remaining: 12.7s
# 673:	learn: 0.4665128	total: 26.3s	remaining: 12.7s
# 674:	learn: 0.4664059	total: 26.3s	remaining: 12.7s
# 675:	learn: 0.4663252	total: 26.3s	remaining: 12.6s
# 676:	learn: 0.4662834	total: 26.4s	remaining: 12.6s
# 677:	learn: 0.4662170	total: 26.4s	remaining: 12.5s
# 678:	learn: 0.4661975	total: 26.4s	remaining: 12.5s
# 679:	learn: 0.4660840	total: 26.5s	remaining: 12.5s
# 680:	learn: 0.4660440	total: 26.5s	remaining: 12.4s
# 681:	learn: 0.4659672	total: 26.5s	remaining: 12.4s
# 682:	learn: 0.4659226	total: 26.6s	remaining: 12.3s
# 683:	learn: 0.4658104	total: 26.6s	remaining: 12.3s
# 684:	learn: 0.4657387	total: 26.7s	remaining: 12.3s
# 685:	learn: 0.4657379	total: 26.7s	remaining: 12.2s
# 686:	learn: 0.4656701	total: 26.7s	remaining: 12.2s
# 687:	learn: 0.4656176	total: 26.7s	remaining: 12.1s
# 688:	learn: 0.4655064	total: 26.8s	remaining: 12.1s
# 689:	learn: 0.4653371	total: 26.8s	remaining: 12s
# 690:	learn: 0.4652781	total: 26.8s	remaining: 12s
# 691:	learn: 0.4652199	total: 26.9s	remaining: 12s
# 692:	learn: 0.4651485	total: 26.9s	remaining: 11.9s
# 693:	learn: 0.4650908	total: 27s	remaining: 11.9s
# 694:	learn: 0.4650249	total: 27s	remaining: 11.8s
# 695:	learn: 0.4649797	total: 27s	remaining: 11.8s
# 696:	learn: 0.4649236	total: 27.1s	remaining: 11.8s
# 697:	learn: 0.4648669	total: 27.1s	remaining: 11.7s
# 698:	learn: 0.4648151	total: 27.1s	remaining: 11.7s
# 699:	learn: 0.4647443	total: 27.2s	remaining: 11.6s
# 700:	learn: 0.4646579	total: 27.2s	remaining: 11.6s
# 701:	learn: 0.4645621	total: 27.2s	remaining: 11.6s
# 702:	learn: 0.4644470	total: 27.3s	remaining: 11.5s
# 703:	learn: 0.4643863	total: 27.3s	remaining: 11.5s
# 704:	learn: 0.4643862	total: 27.4s	remaining: 11.4s
# 705:	learn: 0.4643855	total: 27.4s	remaining: 11.4s
# 706:	learn: 0.4642770	total: 27.5s	remaining: 11.4s
# 707:	learn: 0.4641816	total: 27.5s	remaining: 11.3s
# 708:	learn: 0.4640932	total: 27.5s	remaining: 11.3s
# 709:	learn: 0.4640687	total: 27.6s	remaining: 11.3s
# 710:	learn: 0.4639779	total: 27.6s	remaining: 11.2s
# 711:	learn: 0.4639112	total: 27.7s	remaining: 11.2s
# 712:	learn: 0.4638559	total: 27.7s	remaining: 11.2s
# 713:	learn: 0.4637957	total: 27.8s	remaining: 11.1s
# 714:	learn: 0.4636681	total: 27.8s	remaining: 11.1s
# 715:	learn: 0.4636372	total: 27.8s	remaining: 11s
# 716:	learn: 0.4636339	total: 27.9s	remaining: 11s
# 717:	learn: 0.4635984	total: 28s	remaining: 11s
# 718:	learn: 0.4634615	total: 28s	remaining: 10.9s
# 719:	learn: 0.4633484	total: 28s	remaining: 10.9s
# 720:	learn: 0.4633214	total: 28.1s	remaining: 10.9s
# 721:	learn: 0.4632460	total: 28.1s	remaining: 10.8s
# 722:	learn: 0.4632050	total: 28.2s	remaining: 10.8s
# 723:	learn: 0.4631086	total: 28.2s	remaining: 10.7s
# 724:	learn: 0.4629521	total: 28.3s	remaining: 10.7s
# 725:	learn: 0.4628468	total: 28.3s	remaining: 10.7s
# 726:	learn: 0.4627758	total: 28.4s	remaining: 10.6s
# 727:	learn: 0.4627118	total: 28.4s	remaining: 10.6s
# 728:	learn: 0.4627005	total: 28.4s	remaining: 10.6s
# 729:	learn: 0.4626631	total: 28.5s	remaining: 10.5s
# 730:	learn: 0.4625049	total: 28.5s	remaining: 10.5s
# 731:	learn: 0.4624522	total: 28.5s	remaining: 10.4s
# 732:	learn: 0.4624174	total: 28.6s	remaining: 10.4s
# 733:	learn: 0.4623304	total: 28.6s	remaining: 10.4s
# 734:	learn: 0.4622666	total: 28.6s	remaining: 10.3s
# 735:	learn: 0.4622098	total: 28.7s	remaining: 10.3s
# 736:	learn: 0.4621693	total: 28.7s	remaining: 10.3s
# 737:	learn: 0.4620628	total: 28.8s	remaining: 10.2s
# 738:	learn: 0.4620108	total: 28.8s	remaining: 10.2s
# 739:	learn: 0.4619623	total: 28.8s	remaining: 10.1s
# 740:	learn: 0.4618818	total: 28.9s	remaining: 10.1s
# 741:	learn: 0.4617738	total: 28.9s	remaining: 10s
# 742:	learn: 0.4616621	total: 28.9s	remaining: 10s
# 743:	learn: 0.4616272	total: 29s	remaining: 9.97s
# 744:	learn: 0.4616068	total: 29s	remaining: 9.93s
# 745:	learn: 0.4615493	total: 29s	remaining: 9.89s
# 746:	learn: 0.4614726	total: 29.1s	remaining: 9.85s
# 747:	learn: 0.4614223	total: 29.1s	remaining: 9.81s
# 748:	learn: 0.4613618	total: 29.1s	remaining: 9.77s
# 749:	learn: 0.4613418	total: 29.2s	remaining: 9.73s
# 750:	learn: 0.4613005	total: 29.2s	remaining: 9.69s
# 751:	learn: 0.4612676	total: 29.2s	remaining: 9.64s
# 752:	learn: 0.4612226	total: 29.3s	remaining: 9.61s
# 753:	learn: 0.4611412	total: 29.3s	remaining: 9.56s
# 754:	learn: 0.4611261	total: 29.4s	remaining: 9.53s
# 755:	learn: 0.4610265	total: 29.4s	remaining: 9.48s
# 756:	learn: 0.4609911	total: 29.4s	remaining: 9.45s
# 757:	learn: 0.4609805	total: 29.5s	remaining: 9.4s
# 758:	learn: 0.4608545	total: 29.5s	remaining: 9.37s
# 759:	learn: 0.4607951	total: 29.5s	remaining: 9.33s
# 760:	learn: 0.4607358	total: 29.6s	remaining: 9.29s
# 761:	learn: 0.4606071	total: 29.6s	remaining: 9.24s
# 762:	learn: 0.4605379	total: 29.6s	remaining: 9.21s
# 763:	learn: 0.4604402	total: 29.7s	remaining: 9.16s
# 764:	learn: 0.4603142	total: 29.7s	remaining: 9.13s
# 765:	learn: 0.4602766	total: 29.7s	remaining: 9.08s
# 766:	learn: 0.4602413	total: 29.8s	remaining: 9.04s
# 767:	learn: 0.4601974	total: 29.8s	remaining: 9s
# 768:	learn: 0.4601582	total: 29.9s	remaining: 8.97s
# 769:	learn: 0.4600889	total: 29.9s	remaining: 8.93s
# 770:	learn: 0.4600549	total: 29.9s	remaining: 8.89s
# 771:	learn: 0.4599733	total: 30s	remaining: 8.85s
# 772:	learn: 0.4598913	total: 30s	remaining: 8.81s
# 773:	learn: 0.4598614	total: 30s	remaining: 8.77s
# 774:	learn: 0.4597882	total: 30.1s	remaining: 8.73s
# 775:	learn: 0.4597085	total: 30.1s	remaining: 8.69s
# 776:	learn: 0.4596758	total: 30.1s	remaining: 8.65s
# 777:	learn: 0.4595595	total: 30.2s	remaining: 8.61s
# 778:	learn: 0.4594225	total: 30.2s	remaining: 8.57s
# 779:	learn: 0.4593743	total: 30.2s	remaining: 8.53s
# 780:	learn: 0.4593311	total: 30.3s	remaining: 8.49s
# 781:	learn: 0.4592092	total: 30.3s	remaining: 8.45s
# 782:	learn: 0.4590954	total: 30.3s	remaining: 8.41s
# 783:	learn: 0.4590548	total: 30.4s	remaining: 8.37s
# 784:	learn: 0.4590138	total: 30.5s	remaining: 8.34s
# 785:	learn: 0.4589415	total: 30.5s	remaining: 8.3s
# 786:	learn: 0.4589232	total: 30.5s	remaining: 8.26s
# 787:	learn: 0.4588348	total: 30.6s	remaining: 8.22s
# 788:	learn: 0.4587452	total: 30.6s	remaining: 8.18s
# 789:	learn: 0.4587072	total: 30.6s	remaining: 8.14s
# 790:	learn: 0.4586094	total: 30.7s	remaining: 8.11s
# 791:	learn: 0.4585483	total: 30.7s	remaining: 8.06s
# 792:	learn: 0.4584786	total: 30.7s	remaining: 8.03s
# 793:	learn: 0.4584566	total: 30.8s	remaining: 7.99s
# 794:	learn: 0.4584139	total: 30.8s	remaining: 7.95s
# 795:	learn: 0.4582881	total: 30.9s	remaining: 7.91s
# 796:	learn: 0.4582703	total: 30.9s	remaining: 7.87s
# 797:	learn: 0.4582260	total: 30.9s	remaining: 7.83s
# 798:	learn: 0.4581751	total: 31s	remaining: 7.79s
# 799:	learn: 0.4581746	total: 31s	remaining: 7.75s
# 800:	learn: 0.4580690	total: 31s	remaining: 7.71s
# 801:	learn: 0.4580323	total: 31.1s	remaining: 7.67s
# 802:	learn: 0.4579164	total: 31.1s	remaining: 7.63s
# 803:	learn: 0.4577903	total: 31.1s	remaining: 7.59s
# 804:	learn: 0.4577169	total: 31.2s	remaining: 7.55s
# 805:	learn: 0.4576220	total: 31.2s	remaining: 7.51s
# 806:	learn: 0.4576019	total: 31.2s	remaining: 7.47s
# 807:	learn: 0.4575883	total: 31.3s	remaining: 7.44s
# 808:	learn: 0.4575158	total: 31.4s	remaining: 7.41s
# 809:	learn: 0.4574670	total: 31.4s	remaining: 7.37s
# 810:	learn: 0.4574030	total: 31.4s	remaining: 7.33s
# 811:	learn: 0.4573553	total: 31.5s	remaining: 7.29s
# 812:	learn: 0.4572841	total: 31.5s	remaining: 7.25s
# 813:	learn: 0.4571719	total: 31.6s	remaining: 7.21s
# 814:	learn: 0.4570978	total: 31.6s	remaining: 7.17s
# 815:	learn: 0.4569864	total: 31.6s	remaining: 7.13s
# 816:	learn: 0.4569274	total: 31.7s	remaining: 7.09s
# 817:	learn: 0.4568397	total: 31.7s	remaining: 7.05s
# 818:	learn: 0.4567524	total: 31.7s	remaining: 7.01s
# 819:	learn: 0.4566726	total: 31.8s	remaining: 6.97s
# 820:	learn: 0.4566224	total: 31.8s	remaining: 6.94s
# 821:	learn: 0.4565327	total: 31.8s	remaining: 6.9s
# 822:	learn: 0.4564604	total: 31.9s	remaining: 6.86s
# 823:	learn: 0.4563753	total: 31.9s	remaining: 6.82s
# 824:	learn: 0.4563160	total: 32s	remaining: 6.78s
# 825:	learn: 0.4562807	total: 32s	remaining: 6.74s
# 826:	learn: 0.4562165	total: 32.1s	remaining: 6.71s
# 827:	learn: 0.4560778	total: 32.1s	remaining: 6.67s
# 828:	learn: 0.4560140	total: 32.1s	remaining: 6.63s
# 829:	learn: 0.4559481	total: 32.2s	remaining: 6.59s
# 830:	learn: 0.4559111	total: 32.2s	remaining: 6.55s
# 831:	learn: 0.4558763	total: 32.2s	remaining: 6.51s
# 832:	learn: 0.4558430	total: 32.3s	remaining: 6.47s
# 833:	learn: 0.4557909	total: 32.3s	remaining: 6.43s
# 834:	learn: 0.4557429	total: 32.4s	remaining: 6.39s
# 835:	learn: 0.4556763	total: 32.4s	remaining: 6.35s
# 836:	learn: 0.4555959	total: 32.4s	remaining: 6.31s
# 837:	learn: 0.4555376	total: 32.5s	remaining: 6.27s
# 838:	learn: 0.4554629	total: 32.5s	remaining: 6.23s
# 839:	learn: 0.4553814	total: 32.5s	remaining: 6.2s
# 840:	learn: 0.4553801	total: 32.6s	remaining: 6.16s
# 841:	learn: 0.4553627	total: 32.6s	remaining: 6.12s
# 842:	learn: 0.4552298	total: 32.6s	remaining: 6.08s
# 843:	learn: 0.4551547	total: 32.7s	remaining: 6.04s
# 844:	learn: 0.4550603	total: 32.7s	remaining: 6s
# 845:	learn: 0.4549474	total: 32.8s	remaining: 5.96s
# 846:	learn: 0.4548513	total: 32.8s	remaining: 5.93s
# 847:	learn: 0.4547992	total: 32.8s	remaining: 5.89s
# 848:	learn: 0.4547710	total: 32.9s	remaining: 5.85s
# 849:	learn: 0.4546146	total: 32.9s	remaining: 5.81s
# 850:	learn: 0.4545547	total: 33s	remaining: 5.77s
# 851:	learn: 0.4544906	total: 33s	remaining: 5.73s
# 852:	learn: 0.4543454	total: 33s	remaining: 5.69s
# 853:	learn: 0.4542619	total: 33.1s	remaining: 5.65s
# 854:	learn: 0.4542124	total: 33.1s	remaining: 5.61s
# 855:	learn: 0.4540752	total: 33.1s	remaining: 5.57s
# 856:	learn: 0.4539322	total: 33.2s	remaining: 5.54s
# 857:	learn: 0.4538914	total: 33.2s	remaining: 5.5s
# 858:	learn: 0.4538564	total: 33.3s	remaining: 5.47s
# 859:	learn: 0.4538283	total: 33.4s	remaining: 5.43s
# 860:	learn: 0.4537436	total: 33.4s	remaining: 5.39s
# 861:	learn: 0.4537102	total: 33.4s	remaining: 5.35s
# 862:	learn: 0.4536677	total: 33.5s	remaining: 5.32s
# 863:	learn: 0.4535328	total: 33.5s	remaining: 5.28s
# 864:	learn: 0.4534943	total: 33.6s	remaining: 5.24s
# 865:	learn: 0.4534344	total: 33.6s	remaining: 5.2s
# 866:	learn: 0.4532976	total: 33.6s	remaining: 5.16s
# 867:	learn: 0.4532649	total: 33.7s	remaining: 5.12s
# 868:	learn: 0.4531786	total: 33.7s	remaining: 5.08s
# 869:	learn: 0.4531157	total: 33.8s	remaining: 5.04s
# 870:	learn: 0.4529722	total: 33.8s	remaining: 5.01s
# 871:	learn: 0.4529444	total: 33.9s	remaining: 4.97s
# 872:	learn: 0.4528629	total: 33.9s	remaining: 4.93s
# 873:	learn: 0.4528479	total: 33.9s	remaining: 4.89s
# 874:	learn: 0.4527561	total: 34s	remaining: 4.86s
# 875:	learn: 0.4527414	total: 34s	remaining: 4.82s
# 876:	learn: 0.4526779	total: 34.1s	remaining: 4.78s
# 877:	learn: 0.4526167	total: 34.1s	remaining: 4.74s
# 878:	learn: 0.4525745	total: 34.1s	remaining: 4.7s
# 879:	learn: 0.4524575	total: 34.2s	remaining: 4.66s
# 880:	learn: 0.4524341	total: 34.2s	remaining: 4.62s
# 881:	learn: 0.4523773	total: 34.2s	remaining: 4.58s
# 882:	learn: 0.4523314	total: 34.3s	remaining: 4.54s
# 883:	learn: 0.4521687	total: 34.3s	remaining: 4.5s
# 884:	learn: 0.4520650	total: 34.4s	remaining: 4.46s
# 885:	learn: 0.4519355	total: 34.4s	remaining: 4.42s
# 886:	learn: 0.4519024	total: 34.4s	remaining: 4.39s
# 887:	learn: 0.4518842	total: 34.5s	remaining: 4.35s
# 888:	learn: 0.4517882	total: 34.5s	remaining: 4.31s
# 889:	learn: 0.4516567	total: 34.5s	remaining: 4.27s
# 890:	learn: 0.4516185	total: 34.6s	remaining: 4.23s
# 891:	learn: 0.4515778	total: 34.6s	remaining: 4.19s
# 892:	learn: 0.4515527	total: 34.6s	remaining: 4.15s
# 893:	learn: 0.4515401	total: 34.7s	remaining: 4.11s
# 894:	learn: 0.4514938	total: 34.7s	remaining: 4.07s
# 895:	learn: 0.4514434	total: 34.8s	remaining: 4.03s
# 896:	learn: 0.4514071	total: 34.8s	remaining: 3.99s
# 897:	learn: 0.4513682	total: 34.8s	remaining: 3.96s
# 898:	learn: 0.4513205	total: 34.9s	remaining: 3.92s
# 899:	learn: 0.4512357	total: 34.9s	remaining: 3.88s
# 900:	learn: 0.4511774	total: 34.9s	remaining: 3.84s
# 901:	learn: 0.4511351	total: 35s	remaining: 3.8s
# 902:	learn: 0.4510258	total: 35s	remaining: 3.76s
# 903:	learn: 0.4509931	total: 35s	remaining: 3.72s
# 904:	learn: 0.4509663	total: 35.1s	remaining: 3.68s
# 905:	learn: 0.4508611	total: 35.1s	remaining: 3.64s
# 906:	learn: 0.4507872	total: 35.2s	remaining: 3.6s
# 907:	learn: 0.4507305	total: 35.2s	remaining: 3.56s
# 908:	learn: 0.4506667	total: 35.2s	remaining: 3.53s
# 909:	learn: 0.4506329	total: 35.3s	remaining: 3.49s
# 910:	learn: 0.4506324	total: 35.3s	remaining: 3.45s
# 911:	learn: 0.4505828	total: 35.4s	remaining: 3.41s
# 912:	learn: 0.4504877	total: 35.4s	remaining: 3.37s
# 913:	learn: 0.4504465	total: 35.4s	remaining: 3.33s
# 914:	learn: 0.4503740	total: 35.5s	remaining: 3.29s
# 915:	learn: 0.4503158	total: 35.5s	remaining: 3.25s
# 916:	learn: 0.4501933	total: 35.5s	remaining: 3.22s
# 917:	learn: 0.4500636	total: 35.6s	remaining: 3.18s
# 918:	learn: 0.4499704	total: 35.6s	remaining: 3.14s
# 919:	learn: 0.4498837	total: 35.6s	remaining: 3.1s
# 920:	learn: 0.4498239	total: 35.7s	remaining: 3.06s
# 921:	learn: 0.4497767	total: 35.7s	remaining: 3.02s
# 922:	learn: 0.4496878	total: 35.8s	remaining: 2.98s
# 923:	learn: 0.4496772	total: 35.8s	remaining: 2.94s
# 924:	learn: 0.4496578	total: 35.8s	remaining: 2.9s
# 925:	learn: 0.4495202	total: 35.9s	remaining: 2.87s
# 926:	learn: 0.4494780	total: 35.9s	remaining: 2.83s
# 927:	learn: 0.4494411	total: 35.9s	remaining: 2.79s
# 928:	learn: 0.4494258	total: 36s	remaining: 2.75s
# 929:	learn: 0.4493278	total: 36s	remaining: 2.71s
# 930:	learn: 0.4492784	total: 36.1s	remaining: 2.67s
# 931:	learn: 0.4491732	total: 36.1s	remaining: 2.63s
# 932:	learn: 0.4490644	total: 36.1s	remaining: 2.59s
# 933:	learn: 0.4490085	total: 36.2s	remaining: 2.56s
# 934:	learn: 0.4489660	total: 36.2s	remaining: 2.52s
# 935:	learn: 0.4488917	total: 36.2s	remaining: 2.48s
# 936:	learn: 0.4488595	total: 36.3s	remaining: 2.44s
# 937:	learn: 0.4488040	total: 36.3s	remaining: 2.4s
# 938:	learn: 0.4487455	total: 36.4s	remaining: 2.36s
# 939:	learn: 0.4486612	total: 36.4s	remaining: 2.33s
# 940:	learn: 0.4484874	total: 36.5s	remaining: 2.29s
# 941:	learn: 0.4483754	total: 36.5s	remaining: 2.25s
# 942:	learn: 0.4483251	total: 36.5s	remaining: 2.21s
# 943:	learn: 0.4481916	total: 36.6s	remaining: 2.17s
# 944:	learn: 0.4481530	total: 36.6s	remaining: 2.13s
# 945:	learn: 0.4481399	total: 36.7s	remaining: 2.09s
# 946:	learn: 0.4480098	total: 36.7s	remaining: 2.05s
# 947:	learn: 0.4478879	total: 36.7s	remaining: 2.01s
# 948:	learn: 0.4478545	total: 36.8s	remaining: 1.98s
# 949:	learn: 0.4477908	total: 36.8s	remaining: 1.94s
# 950:	learn: 0.4477312	total: 36.9s	remaining: 1.9s
# 951:	learn: 0.4476167	total: 36.9s	remaining: 1.86s
# 952:	learn: 0.4475365	total: 36.9s	remaining: 1.82s
# 953:	learn: 0.4474525	total: 37s	remaining: 1.78s
# 954:	learn: 0.4473203	total: 37s	remaining: 1.74s
# 955:	learn: 0.4472651	total: 37.1s	remaining: 1.71s
# 956:	learn: 0.4472001	total: 37.1s	remaining: 1.67s
# 957:	learn: 0.4470981	total: 37.1s	remaining: 1.63s
# 958:	learn: 0.4470648	total: 37.2s	remaining: 1.59s
# 959:	learn: 0.4470280	total: 37.2s	remaining: 1.55s
# 960:	learn: 0.4469751	total: 37.3s	remaining: 1.51s
# 961:	learn: 0.4469347	total: 37.3s	remaining: 1.47s
# 962:	learn: 0.4468456	total: 37.4s	remaining: 1.44s
# 963:	learn: 0.4467675	total: 37.4s	remaining: 1.4s
# 964:	learn: 0.4466756	total: 37.4s	remaining: 1.36s
# 965:	learn: 0.4466302	total: 37.5s	remaining: 1.32s
# 966:	learn: 0.4465488	total: 37.5s	remaining: 1.28s
# 967:	learn: 0.4465053	total: 37.6s	remaining: 1.24s
# 968:	learn: 0.4464247	total: 37.6s	remaining: 1.2s
# 969:	learn: 0.4464125	total: 37.6s	remaining: 1.16s
# 970:	learn: 0.4463758	total: 37.7s	remaining: 1.13s
# 971:	learn: 0.4462955	total: 37.7s	remaining: 1.09s
# 972:	learn: 0.4462517	total: 37.8s	remaining: 1.05s
# 973:	learn: 0.4462252	total: 37.8s	remaining: 1.01s
# 974:	learn: 0.4460725	total: 37.9s	remaining: 972ms
# 975:	learn: 0.4459946	total: 38s	remaining: 933ms
# 976:	learn: 0.4459144	total: 38s	remaining: 894ms
# 977:	learn: 0.4458426	total: 38s	remaining: 855ms
# 978:	learn: 0.4458118	total: 38.1s	remaining: 816ms
# 979:	learn: 0.4457064	total: 38.1s	remaining: 777ms
# 980:	learn: 0.4456278	total: 38.1s	remaining: 739ms
# 981:	learn: 0.4455559	total: 38.2s	remaining: 700ms
# 982:	learn: 0.4455099	total: 38.2s	remaining: 661ms
# 983:	learn: 0.4454150	total: 38.2s	remaining: 622ms
# 984:	learn: 0.4453295	total: 38.3s	remaining: 583ms
# 985:	learn: 0.4452678	total: 38.3s	remaining: 544ms
# 986:	learn: 0.4451921	total: 38.4s	remaining: 505ms
# 987:	learn: 0.4451521	total: 38.4s	remaining: 466ms
# 988:	learn: 0.4451064	total: 38.4s	remaining: 427ms
# 989:	learn: 0.4450552	total: 38.5s	remaining: 388ms
# 990:	learn: 0.4450297	total: 38.5s	remaining: 350ms
# 991:	learn: 0.4449119	total: 38.5s	remaining: 311ms
# 992:	learn: 0.4448072	total: 38.6s	remaining: 272ms
# 993:	learn: 0.4447744	total: 38.6s	remaining: 233ms
# 994:	learn: 0.4447009	total: 38.6s	remaining: 194ms
# 995:	learn: 0.4445627	total: 38.7s	remaining: 155ms
# 996:	learn: 0.4445301	total: 38.7s	remaining: 116ms
# 997:	learn: 0.4444955	total: 38.7s	remaining: 77.6ms
# 998:	learn: 0.4444345	total: 38.8s	remaining: 38.8ms
# 999:	learn: 0.4444306	total: 38.8s	remaining: 0us

# %%
### Замерим качество работы такой модели
### Возьмем MSLE

train_preds = catboost.predict(X_train)
test_preds = catboost.predict(X_test)

train_error = np.mean((train_preds - y_train.values.ravel())**2)
test_error = np.mean((test_preds - y_test.values.ravel())**2)


print(f"Качество на трейне: {train_error.round(3)}")
print(f"Качество на тесте: {test_error.round(3)}")
# Out:
# Качество на трейне: 0.206
# Качество на тесте: 0.326
