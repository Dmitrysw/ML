# %%
import torch
import torch.nn as nn

# %%
#Создание объекта нейросети
net = nn.Sequential(nn.Linear(700, 500), nn.ReLU(), nn.Linear(500, 200), nn.ReLU(), nn.Linear(200, 10))

# %%
net
# Out:
# Sequential(
#   (0): Linear(in_features=700, out_features=500, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=500, out_features=200, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=200, out_features=10, bias=True)
# )

# %%
#Точно также создадим сеть, но теперь слои имеют название

from collections import OrderedDict

net = nn.Sequential(
    OrderedDict(
        [
            ('linear1', nn.Linear(700, 500)),
            ('relu1', nn.ReLU()),
            ('linear2', nn.Linear(500, 200)),
            ('relu2', nn.ReLU()),
            ('linear3', nn.Linear(200, 10))
        ]
    )
)

# %%
#Можно получить доступ к любому слою сети, весам любого слоя и т.д.
net.linear1
# Out:
# Linear(in_features=700, out_features=500, bias=True)

# %%
#создадим какой-то входной тензор
input_tensor = torch.rand(10, 700)

net(input_tensor).shape
# Out:
# torch.Size([10, 10])

# %%
class CustomTaskNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        self.linear1 = nn.Linear(700, 500)
        self.linear2 = nn.Linear(500, 200)
        self.linear3 = nn.Linear(200, 10)

        self.activations = nn.ReLU()

    def forward(self, x):
        output = self.activations(self.linear1(x))
        output = self.activations(self.linear2(output))
        output = self.linear3(output)

        return output

# %%
net = CustomTaskNetwork()
net(input_tensor).shape
# Out:
# torch.Size([10, 10])

# %%
#перемещение сети на гпу
#net.to()

# %%
#train - тренировка сети, вычисление градиентов и всё такое сякое
#евал - это работа сети в режиме предсказаний, градиенты не считаются в этот момент
net.train()
net.eval()
# заморозка части слоёв
net.requires_grad_()
# Out:
# CustomTaskNetwork(
#   (linear1): Linear(in_features=700, out_features=500, bias=True)
#   (linear2): Linear(in_features=500, out_features=200, bias=True)
#   (linear3): Linear(in_features=200, out_features=10, bias=True)
#   (activations): ReLU()
# )

# %%
list(net.parameters())
# Out:
# [Parameter containing:
#  tensor([[ 0.0170,  0.0038,  0.0080,  ...,  0.0301,  0.0309,  0.0088],
#          [-0.0067, -0.0186, -0.0041,  ..., -0.0070,  0.0048,  0.0252],
#          [-0.0266, -0.0003,  0.0043,  ..., -0.0192, -0.0318, -0.0190],
#          ...,
#          [ 0.0306, -0.0021,  0.0048,  ...,  0.0196,  0.0122, -0.0199],
#          [-0.0158, -0.0084, -0.0276,  ..., -0.0262,  0.0265,  0.0018],
#          [ 0.0040, -0.0247,  0.0376,  ...,  0.0128,  0.0102, -0.0139]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([ 1.2599e-02,  2.3634e-02,  3.1302e-03, -2.6670e-02,  9.1454e-03,
#          -3.4555e-02,  1.2547e-02, -4.1844e-03,  2.7773e-02, -2.7672e-02,
#           1.8957e-02, -1.4012e-03, -2.0991e-02,  7.3393e-03, -1.2401e-02,
#          -8.5118e-03,  2.6291e-02, -2.6440e-02,  3.3514e-02, -2.4662e-02,
#          -2.5853e-02,  1.4202e-02,  2.2114e-02,  9.1471e-03,  1.8276e-02,
#           1.8183e-02, -3.0803e-02, -2.4727e-02, -3.4196e-02, -3.1766e-02,
#          -3.6923e-02,  7.8870e-03,  2.3023e-02,  2.9881e-02,  2.5473e-02,
#           1.6761e-02,  6.2757e-03, -7.0203e-03, -2.3985e-02, -5.1025e-03,
#                        0.0447,  0.0260, -0.0353,  0.0146,  0.0091, -0.0017, -0.0334, -0.0175,
#                        0.0087, -0.0044, -0.0124,  0.0009, -0.0284, -0.0168, -0.0411,  0.0043,
#                       -0.0278,  0.0416, -0.0138,  0.0308, -0.0085,  0.0155, -0.0262, -0.0022,
#                        0.0433,  0.0337, -0.0031,  0.0350, -0.0400, -0.0155,  0.0156, -0.0415,
#                       -0.0133, -0.0136,  0.0325, -0.0333, -0.0177,  0.0273, -0.0184,  0.0104,
#                        0.0162,  0.0421, -0.0420,  0.0244, -0.0330,  0.0025,  0.0001, -0.0252,
#                        0.0215,  0.0333,  0.0286,  0.0257,  0.0143,  0.0040, -0.0236, -0.0198])),
#              ('linear3.weight',
#               tensor([[ 0.0180, -0.0537, -0.0508,  ...,  0.0004,  0.0021,  0.0401],
#                       [ 0.0473,  0.0265,  0.0448,  ..., -0.0507, -0.0322, -0.0692],
#                       [-0.0587, -0.0061, -0.0133,  ...,  0.0334, -0.0393, -0.0082],
#                       ...,
#                       [-0.0104,  0.0216, -0.0555,  ...,  0.0343,  0.0185,  0.0005],
#                       [-0.0303,  0.0319, -0.0128,  ...,  0.0269, -0.0440, -0.0577],
#                       [ 0.0363, -0.0016, -0.0035,  ...,  0.0703, -0.0246,  0.0386]])),
#              ('linear3.bias',
#               tensor([ 0.0689,  0.0638, -0.0042,  0.0050,  0.0362, -0.0358,  0.0193,  0.0209,
#                        0.0331,  0.0078]))])

# %%
net.load_state_dict(net.state_dict())
# Out:
# <All keys matched successfully>

# %% [markdown]
# Оптимизаторы

# %%
from torch import optim

# %%
optim.SGD, optim.Adam
# Out:
# (torch.optim.sgd.SGD, torch.optim.adam.Adam)

# %%
#передаем в оптимайзер параметры нашей сети и длину шага
optimizer = optim.Adam(net.parameters(), lr=0.0001)

# %%
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: False
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0
# )

# %%
#оптимизируем только первый и второй слой, при этом шаг на втором слое особый
optimizer = optim.SGD(
    [
        {"params": net.linear1.parameters()},
        {"params": net.linear2.parameters(), "lr": 1e-3}
    ],
    lr=1e-2,
    momentum=0.9
)

# %%
#делаем шаг оптимайзера
optimizer.step()

# %%
#после этого нужно обнулить градиенты
optimizer.zero_grad()

# %% [markdown]
# Функции потерь

# %%
nn.L1Loss, nn.MSELoss, nn.CrossEntropyLoss
# Out:
# (torch.nn.modules.loss.L1Loss,
#  torch.nn.modules.loss.MSELoss,
#  torch.nn.modules.loss.CrossEntropyLoss)

# %%
loss = nn.MSELoss()

# %%
input = torch.randn(3, 5, requires_grad=True)
target = torch.randn(3, 5)

output = loss(input, target)

print(output)

output.backward()
# Out:
# tensor(1.9503, grad_fn=<MseLossBackward0>)

# %%
input.grad
# Out:
# tensor([[ 0.2655,  0.0821,  0.0948,  0.1920, -0.1090],
#         [ 0.2002,  0.0061, -0.4460, -0.3261, -0.0722],
#         [ 0.0716, -0.0791,  0.0780,  0.0192, -0.1291]])

# %% [markdown]
# Датасеты и даталоадеры

# %%
from torch.utils.data import Dataset
from torch.utils.data import TensorDataset

# %%
n_features = 2
n_objects = 300

# %%
w_true = torch.randn(n_features)
X = (torch.rand(n_objects, n_features) - 0.5) * 10
X *= (torch.arange(n_features) * 2 + 1)
Y = (X @ w_true + torch.randn(n_objects)).unsqueeze(1)

# %%
dataset = TensorDataset(X, Y)

# %%
dataset[0]
# Out:
# (tensor([ 0.6620, -3.8205]), tensor([2.3141]))

# %%
X[0]
# Out:
# tensor([ 0.6620, -3.8205])

# %%
class CustomDataset(Dataset):
    def __init__(self, w_true, n_features, n_objects):
        self.X = (torch.rand(n_objects, n_features) - 0.5) * 10
        self.X *= (torch.arange(n_features) * 2 + 1)
        self.Y = self.X @ w_true + torch.randn(n_objects)

    def __len__(self):
        return len(self.Y)
    def __getitem__(self, item):
        return self.Y[item], self.Y[item]

# %%
dataset = CustomDataset(w_true, n_features, n_objects)

# %%
dataset[0]
# Out:
# (tensor(4.0013), tensor(4.0013))

# %%
len(dataset)
# Out:
# 300

# %%
from torch.utils.data import DataLoader

# %%
loader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
for x, y in loader:
    print(x.shape)
# Out:
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])
# torch.Size([4])

# %%
X.shape
# Out:
# torch.Size([300, 2])

# %% [markdown]
# Общая структура обученя модели

# %%
model.train()

for x, y in dataloader:
    optimizer.zero_grad()
    output = model(x)
    loss = loss_fn(output, y)
    loss.backward()
    optimizer.step()
#один проход по даталоадеру называется одной эпохой
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [51], line 1
# ----> 1 model.train()
#       3 for x, y in dataloader:
#       4     optimizer.zero_grad()
#
# NameError: name 'model' is not defined

# %%
#Обучение первой нейросети

# %%
class CustomTaskNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(n_features, 1)

    def forward(self, x):
        return self.linear(x)

net = CustomTaskNetwork()
optimizer = optim.Adam(net.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()
dataset = TensorDataset(X, Y)
loader = DataLoader(dataset, batch_size=4, shuffle=True)
w_list = torch.empty(len(loader) + 1, n_features)

# %%
net.train()

for i, (x, y) in enumerate(loader):
    w_list[i] = net.linear.weight.detach().clone()
    optimizer.zero_grad()
    output = net(x)
    loss = loss_fn(output, y)
    print(f"MSE на шаге {i}{loss.item():.5f}")
    loss.backward()
    optimizer.step()
w_list[len(loader)] = net.linear.weight.detach().clone()
# Out:
# MSE на шаге 0217.99582
# MSE на шаге 1126.96246
# MSE на шаге 212.73696
# MSE на шаге 3211.95782
# MSE на шаге 4143.79070
# MSE на шаге 551.79517
# MSE на шаге 646.10628
# MSE на шаге 7127.66228
# MSE на шаге 865.56555
# MSE на шаге 9225.13774
# MSE на шаге 10144.68591
# MSE на шаге 11167.69485
# MSE на шаге 1298.50328
# MSE на шаге 13260.62180
# MSE на шаге 14127.47001
# MSE на шаге 1589.41429
# MSE на шаге 16103.75901
# MSE на шаге 17157.29520
# MSE на шаге 1852.60718
# MSE на шаге 19110.64365
# MSE на шаге 20153.16663
# MSE на шаге 21113.24628
# MSE на шаге 22159.59294
# MSE на шаге 2383.95333
# MSE на шаге 2430.33527
# MSE на шаге 25135.09601
# MSE на шаге 26182.72141
# MSE на шаге 2739.79673
# MSE на шаге 28118.58049
# MSE на шаге 2971.92991
# MSE на шаге 30154.70557
# MSE на шаге 31154.95154
# MSE на шаге 32103.77626
# MSE на шаге 33161.37579
# MSE на шаге 34104.29935
# MSE на шаге 3598.15703
# MSE на шаге 3624.29409
# MSE на шаге 37128.90590
# MSE на шаге 38102.43903
# MSE на шаге 3986.79538
# MSE на шаге 40139.18016
# MSE на шаге 41244.20355
# MSE на шаге 42138.68585
# MSE на шаге 4376.75214
# MSE на шаге 44108.08797
# MSE на шаге 4566.21972
# MSE на шаге 46103.76307
# MSE на шаге 4746.07059
# MSE на шаге 48222.71095
# MSE на шаге 49130.57364
# MSE на шаге 5083.93961
# MSE на шаге 5129.54607
# MSE на шаге 52117.44446
# MSE на шаге 5339.22622
# MSE на шаге 54146.43359
# MSE на шаге 5546.20465
# MSE на шаге 56253.74232
# MSE на шаге 5727.05514
# MSE на шаге 5829.42977
# MSE на шаге 59138.65648
# MSE на шаге 6051.21896
# MSE на шаге 61145.32718
# MSE на шаге 62150.67433
# MSE на шаге 6390.93600
# MSE на шаге 64212.66647
# MSE на шаге 65284.54520
# MSE на шаге 6699.96081
# MSE на шаге 67102.81403
# MSE на шаге 68142.30092
# MSE на шаге 6998.59198
# MSE на шаге 7052.93386
# MSE на шаге 71133.89018
# MSE на шаге 72165.10089
# MSE на шаге 73110.96534
# MSE на шаге 74127.21986

# %%
import numpy as np
import pandas as pd


CON = "postgresql://robot-startml-ro:pheiph0hahj1Vaif@postgres.lab.karpov.courses:6432/startml"


def select(query: str) -> pd.DataFrame:
    global CON
    return pd.read_sql(query, CON)


q = """
SELECT fa.post_id,
       fa.time,
       u.age,
       u.os
FROM   feed_action AS fa
       JOIN "user" AS u
         ON u.id = fa.user_id
WHERE  u.city = 'Omsk'
       AND
       fa.action = 'like'
ORDER  BY fa.time DESC
LIMIT  100
"""

result = select(q)
result.to_csv("Python_HW_6_Task_15.csv", sep=",", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 28
#      10     return pd.read_sql(query, CON)
#      13 q = """
#      14 SELECT fa.post_id,
#      15        fa.time,
#    (...)
#      25 LIMIT  100
#      26 """
# ---> 28 result = select(q)
#      29 result.to_csv("Python_HW_6_Task_15.csv", sep=",", index=False)
#
# Cell In [7], line 10, in select(query)
#       8 def select(query: str) -> pd.DataFrame:
#       9     global CON
# ---> 10     return pd.read_sql(query, CON)
#
# File E:\ML\lib\site-packages\pandas\io\sql.py:591, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     582     return pandas_sql.read_table(
#     583         sql,
#     584         index_col=index_col,
#    (...)
#     588         chunksize=chunksize,
#     589     )
#     590 else:
# --> 591     return pandas_sql.read_query(
#     592         sql,
#     593         index_col=index_col,
#     594         params=params,
#     595         coerce_float=coerce_float,
#     596         parse_dates=parse_dates,
#     597         chunksize=chunksize,
#     598     )
#
# File E:\ML\lib\site-packages\pandas\io\sql.py:1561, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1513 """
#    1514 Read SQL query into a DataFrame.
#    1515
#    (...)
#    1557
#    1558 """
#    1559 args = _convert_params(sql, params)
# -> 1561 result = self.execute(*args)
#    1562 columns = result.keys()
#    1564 if chunksize is not None:
#
# File E:\ML\lib\site-packages\pandas\io\sql.py:1406, in SQLDatabase.execute(self, *args, **kwargs)
#    1404 def execute(self, *args, **kwargs):
#    1405     """Simple passthrough to SQLAlchemy connectable"""
# -> 1406     return self.connectable.execution_options().execute(*args, **kwargs)
#
# AttributeError: 'OptionEngine' object has no attribute 'execute'
